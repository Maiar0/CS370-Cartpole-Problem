# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    scores = []  # To keep track of the last 100 scores
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)
                
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9137248860125932, score: 22
# Scores: (min: 16, avg: 19, max: 22)
#
# Run: 3, exploration: 0.736559652908221, score: 44
# Scores: (min: 16, avg: 27.333333333333332, max: 44)
#
# Run: 4, exploration: 0.6900935609921609, score: 14
# Scores: (min: 14, avg: 24, max: 44)
#
# Run: 5, exploration: 0.5819594443402982, score: 35
# Scores: (min: 14, avg: 26.2, max: 44)
#
# Run: 6, exploration: 0.547986285490042, score: 13
# Scores: (min: 13, avg: 24, max: 44)
#
# Run: 7, exploration: 0.5185893309484582, score: 12
# Scores: (min: 12, avg: 22.285714285714285, max: 44)
#
# Run: 8, exploration: 0.4932355662165453, score: 11
# Scores: (min: 11, avg: 20.875, max: 44)
#
# Run: 9, exploration: 0.45522245551230495, score: 17
# Scores: (min: 11, avg: 20.444444444444443, max: 44)
#
# Run: 10, exploration: 0.4180382776616619, score: 18
# Scores: (min: 11, avg: 20.2, max: 44)
#
# Run: 11, exploration: 0.3936343764094253, score: 13
# Scores: (min: 11, avg: 19.545454545454547, max: 44)
#
# Run: 12, exploration: 0.3596735257153405, score: 19
# Scores: (min: 11, avg: 19.5, max: 44)
#
# Run: 13, exploration: 0.33698341088258443, score: 14
# Scores: (min: 11, avg: 19.076923076923077, max: 44)
#
# Run: 14, exploration: 0.3237376186352221, score: 9
# Scores: (min: 9, avg: 18.357142857142858, max: 44)
#
# Run: 15, exploration: 0.31101247816653554, score: 9
# Scores: (min: 9, avg: 17.733333333333334, max: 44)
#
# Run: 16, exploration: 0.29580711868545667, score: 11
# Scores: (min: 9, avg: 17.3125, max: 44)
#
# Run: 17, exploration: 0.2827589419554058, score: 10
# Scores: (min: 9, avg: 16.88235294117647, max: 44)
#
# Run: 18, exploration: 0.2730095965279488, score: 8
# Scores: (min: 8, avg: 16.38888888888889, max: 44)
#
# Run: 19, exploration: 0.26227842021373715, score: 9
# Scores: (min: 8, avg: 16, max: 44)
#
# Run: 20, exploration: 0.24696734223472733, score: 13
# Scores: (min: 8, avg: 15.85, max: 44)
#
# Run: 21, exploration: 0.231387331601191, score: 14
# Scores: (min: 8, avg: 15.761904761904763, max: 44)
#
# Run: 22, exploration: 0.22229219984074702, score: 9
# Scores: (min: 8, avg: 15.454545454545455, max: 44)
#
# Run: 23, exploration: 0.21248679717794605, score: 10
# Scores: (min: 8, avg: 15.217391304347826, max: 44)
#
# Run: 24, exploration: 0.2000824143909432, score: 13
# Scores: (min: 8, avg: 15.125, max: 44)
#
# Run: 25, exploration: 0.19318370215794672, score: 8
# Scores: (min: 8, avg: 14.84, max: 44)
#
# Run: 26, exploration: 0.1846622876013121, score: 10
# Scores: (min: 8, avg: 14.653846153846153, max: 44)
#
# Run: 27, exploration: 0.17651675623376062, score: 10
# Scores: (min: 8, avg: 14.481481481481481, max: 44)
#
# Run: 28, exploration: 0.1678868750508869, score: 11
# Scores: (min: 8, avg: 14.357142857142858, max: 44)
#
# Run: 29, exploration: 0.16128775296900558, score: 9
# Scores: (min: 8, avg: 14.172413793103448, max: 44)
#
# Run: 30, exploration: 0.15417328217978102, score: 10
# Scores: (min: 8, avg: 14.033333333333333, max: 44)
#
# Run: 31, exploration: 0.14229132060898236, score: 17
# Scores: (min: 8, avg: 14.129032258064516, max: 44)
#
# Run: 32, exploration: 0.13601479046086049, score: 10
# Scores: (min: 8, avg: 14, max: 44)
#
# Run: 33, exploration: 0.1313250884614265, score: 8
# Scores: (min: 8, avg: 13.818181818181818, max: 44)
#
# Run: 34, exploration: 0.1261630989318213, score: 9
# Scores: (min: 8, avg: 13.676470588235293, max: 44)
#
# Run: 35, exploration: 0.12059799144222175, score: 10
# Scores: (min: 8, avg: 13.571428571428571, max: 44)
#
# Run: 36, exploration: 0.11643985070121858, score: 8
# Scores: (min: 8, avg: 13.416666666666666, max: 44)
#
# Run: 37, exploration: 0.11186295456362313, score: 9
# Scores: (min: 8, avg: 13.297297297297296, max: 44)
#
# Run: 38, exploration: 0.10692863247165257, score: 10
# Scores: (min: 8, avg: 13.210526315789474, max: 44)
#
# Run: 39, exploration: 0.1032418023864836, score: 8
# Scores: (min: 8, avg: 13.076923076923077, max: 44)
#
# Run: 40, exploration: 0.09868776295209031, score: 10
# Scores: (min: 8, avg: 13, max: 44)
#
# Run: 41, exploration: 0.0943346041173244, score: 10
# Scores: (min: 8, avg: 12.926829268292684, max: 44)
#
# Run: 42, exploration: 0.09108200798387568, score: 8
# Scores: (min: 8, avg: 12.80952380952381, max: 44)
#
# Run: 43, exploration: 0.08662902049662846, score: 11
# Scores: (min: 8, avg: 12.767441860465116, max: 44)
#
# Run: 44, exploration: 0.08239373898667031, score: 11
# Scores: (min: 8, avg: 12.727272727272727, max: 44)
#
# Run: 45, exploration: 0.07875931641927113, score: 10
# Scores: (min: 8, avg: 12.666666666666666, max: 44)
#
# Run: 46, exploration: 0.07604374613140748, score: 8
# Scores: (min: 8, avg: 12.565217391304348, max: 44)
#
# Run: 47, exploration: 0.07342180695061275, score: 8
# Scores: (min: 8, avg: 12.46808510638298, max: 44)
#
# Run: 48, exploration: 0.06983222438783, score: 11
# Scores: (min: 8, avg: 12.4375, max: 44)
#
# Run: 49, exploration: 0.0660860453679829, score: 12
# Scores: (min: 8, avg: 12.428571428571429, max: 44)
#
# Run: 50, exploration: 0.06254083169574957, score: 12
# Scores: (min: 8, avg: 12.42, max: 44)
#
# Run: 51, exploration: 0.05143559895690903, score: 40
# Scores: (min: 8, avg: 12.96078431372549, max: 44)
#
# Run: 52, exploration: 0.03963364364733769, score: 53
# Scores: (min: 8, avg: 13.73076923076923, max: 53)
#
# Run: 53, exploration: 0.03275978694079333, score: 39
# Scores: (min: 8, avg: 14.20754716981132, max: 53)
#
# Run: 54, exploration: 0.025116802354115567, score: 54
# Scores: (min: 8, avg: 14.944444444444445, max: 54)
#
# Run: 55, exploration: 0.022381810029994047, score: 24
# Scores: (min: 8, avg: 15.10909090909091, max: 54)
#
# Run: 56, exploration: 0.020246819920648168, score: 21
# Scores: (min: 8, avg: 15.214285714285714, max: 54)
#
# Run: 57, exploration: 0.017772843617388175, score: 27
# Scores: (min: 8, avg: 15.421052631578947, max: 54)
#
# Run: 58, exploration: 0.01583754189442009, score: 24
# Scores: (min: 8, avg: 15.568965517241379, max: 54)
#
# Run: 59, exploration: 0.014255172347583332, score: 22
# Scores: (min: 8, avg: 15.677966101694915, max: 54)
#
# Run: 60, exploration: 0.012639398604785928, score: 25
# Scores: (min: 8, avg: 15.833333333333334, max: 54)
#
# Run: 61, exploration: 0.01098430721937979, score: 29
# Scores: (min: 8, avg: 16.049180327868854, max: 54)
#
# Run: 62, exploration: 0.010239902030817916, score: 15
# Scores: (min: 8, avg: 16.032258064516128, max: 54)
#
# Run: 63, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.126984126984127, max: 54)
#
# Run: 64, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.1875, max: 54)
#
# Run: 65, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.184615384615384, max: 54)
#
# Run: 66, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.257575757575758, max: 54)
#
# Run: 67, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.253731343283583, max: 54)
#
# Run: 68, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.38235294117647, max: 54)
#
# Run: 69, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.492753623188406, max: 54)
#
# Run: 70, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.47142857142857, max: 54)
#
# Run: 71, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.492957746478872, max: 54)
#
# Run: 72, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.48611111111111, max: 54)
#
# Run: 73, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.465753424657535, max: 54)
#
# Run: 74, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.54054054054054, max: 54)
#
# Run: 75, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.546666666666667, max: 54)
#
# Run: 76, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.723684210526315, max: 54)
#
# Run: 77, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.727272727272727, max: 54)
#
# Run: 78, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.73076923076923, max: 54)
#
# Run: 79, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.746835443037973, max: 54)
#
# Run: 80, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.8375, max: 54)
#
# Run: 81, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.938271604938272, max: 54)
#
# Run: 82, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.085365853658537, max: 54)
#
# Run: 83, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.216867469879517, max: 54)
#
# Run: 84, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.285714285714285, max: 54)
#
# Run: 85, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.270588235294117, max: 54)
# Run: 86, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.24418604651163, max: 54)
#
# Run: 87, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.517241379310345, max: 54)
#
# Run: 88, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.511363636363637, max: 54)
#
# Run: 89, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 17.719101123595507, max: 54)
#
# Run: 90, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 17.92222222222222, max: 54)
#
# Run: 91, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 18.186813186813186, max: 54)
#
# Run: 92, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 18.52173913043478, max: 54)
#
# Run: 93, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.56989247311828, max: 54)
#
# Run: 94, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 19.04255319148936, max: 63)
#
# Run: 95, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 19.210526315789473, max: 63)
#
# Run: 96, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 19.75, max: 71)
#
# Run: 97, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 20.47422680412371, max: 90)
#
# Run: 98, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 20.959183673469386, max: 90)
#
# Run: 99, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 21.404040404040405, max: 90)
#
# Run: 100, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 21.93, max: 90)
#
# Run: 101, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 23.2, max: 143)
#
# Run: 102, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 23.95, max: 143)
#
# Run: 103, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 24.67, max: 143)
#
# Run: 104, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 26.1, max: 157)
#
# Run: 105, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 26.94, max: 157)
#
# Run: 106, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 27.72, max: 157)
#
# Run: 107, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 29.08, max: 157)
#
# Run: 108, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 30.29, max: 157)
#
# Run: 109, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 31.18, max: 157)
#
# Run: 110, exploration: 0.01, score: 348
# Scores: (min: 8, avg: 34.48, max: 348)
#
# Run: 111, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 35.36, max: 348)
#
# Run: 112, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 36.33, max: 348)
#
# Run: 113, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 37.24, max: 348)
#
# Run: 114, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 38.43, max: 348)
#
# Run: 115, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 40.24, max: 348)
#
# Run: 116, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 41.53, max: 348)
#
# Run: 117, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 43.27, max: 348)
#
# Run: 118, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 44.74, max: 348)
#
# Run: 119, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 46.26, max: 348)
#
# Run: 120, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 47.54, max: 348)
#
# Run: 121, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 49.19, max: 348)
#
# Run: 122, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 50.78, max: 348)
#
# Run: 123, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 52.53, max: 348)
#
# Run: 124, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 54.29, max: 348)
#
# Run: 125, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 56.35, max: 348)
#
# Run: 126, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 57.88, max: 348)
#
# Run: 127, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 59.34, max: 348)
#
# Run: 128, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 60.48, max: 348)
#
# Run: 129, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 62.46, max: 348)
#
# Run: 130, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 64.34, max: 348)
#
# Run: 131, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 65.84, max: 348)
#
# Run: 132, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 67.4, max: 348)
#
# Run: 133, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 68.79, max: 348)
#
# Run: 134, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 70.15, max: 348)
#
# Run: 135, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 71.56, max: 348)
#
# Run: 136, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 73.03, max: 348)
#
# Run: 137, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 74.65, max: 348)
#
# Run: 138, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 76.02, max: 348)
#
# Run: 139, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 78.78, max: 348)
#
# Run: 140, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 80.52, max: 348)
#
# Run: 141, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 81.91, max: 348)
#
# Run: 142, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 83.58, max: 348)
#
# Run: 143, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 85.08, max: 348)
#
# Run: 144, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 87.06, max: 348)
#
# Run: 145, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 88.51, max: 348)
#
# Run: 146, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 90.36, max: 348)
#
# Run: 147, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 92.14, max: 348)
#
# Run: 148, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 93.58, max: 348)
#
# Run: 149, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 95.05, max: 348)
#
# Run: 150, exploration: 0.01, score: 285
# Scores: (min: 15, avg: 97.78, max: 348)
#
# Run: 151, exploration: 0.01, score: 248
# Scores: (min: 15, avg: 99.86, max: 348)
#
# Run: 152, exploration: 0.01, score: 175
# Scores: (min: 15, avg: 101.08, max: 348)
#
# Run: 153, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 102.45, max: 348)
#
# Run: 154, exploration: 0.01, score: 64
# Scores: (min: 15, avg: 102.55, max: 348)
#
# Run: 155, exploration: 0.01, score: 174
# Scores: (min: 15, avg: 104.05, max: 348)
#
# Run: 156, exploration: 0.01, score: 196
# Scores: (min: 15, avg: 105.8, max: 348)
#
# Run: 157, exploration: 0.01, score: 144
# Scores: (min: 15, avg: 106.97, max: 348)
#
# Run: 158, exploration: 0.01, score: 175
# Scores: (min: 15, avg: 108.48, max: 348)
#
# Run: 159, exploration: 0.01, score: 251
# Scores: (min: 15, avg: 110.77, max: 348)
#
# Run: 160, exploration: 0.01, score: 135
# Scores: (min: 15, avg: 111.87, max: 348)
#
# Run: 161, exploration: 0.01, score: 171
# Scores: (min: 15, avg: 113.29, max: 348)
#
# Run: 162, exploration: 0.01, score: 117
# Scores: (min: 15, avg: 114.31, max: 348)
#
# Run: 163, exploration: 0.01, score: 172
# Scores: (min: 15, avg: 115.81, max: 348)
#
# Run: 164, exploration: 0.01, score: 233
# Scores: (min: 15, avg: 117.94, max: 348)
#
# Run: 165, exploration: 0.01, score: 136
# Scores: (min: 15, avg: 119.14, max: 348)
#
# Run: 166, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 120.69, max: 348)
#
# Run: 167, exploration: 0.01, score: 144
# Scores: (min: 15, avg: 121.97, max: 348)
#
# Run: 168, exploration: 0.01, score: 197
# Scores: (min: 15, avg: 123.69, max: 348)
#
# Run: 169, exploration: 0.01, score: 126
# Scores: (min: 15, avg: 124.71, max: 348)
#
# Run: 170, exploration: 0.01, score: 211
# Scores: (min: 15, avg: 126.67, max: 348)
#
# Run: 171, exploration: 0.01, score: 167
# Scores: (min: 15, avg: 128.16, max: 348)
#
# Run: 172, exploration: 0.01, score: 196
# Scores: (min: 15, avg: 129.96, max: 348)
#
# Run: 173, exploration: 0.01, score: 182
# Scores: (min: 15, avg: 131.63, max: 348)
#
# Run: 174, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 132.81, max: 348)
#
# Run: 175, exploration: 0.01, score: 234
# Scores: (min: 15, avg: 134.98, max: 348)
#
# Run: 176, exploration: 0.01, score: 236
# Scores: (min: 15, avg: 137.04, max: 348)
#
# Run: 177, exploration: 0.01, score: 334
# Scores: (min: 15, avg: 140.21, max: 348)
#
# Run: 178, exploration: 0.01, score: 205
# Scores: (min: 15, avg: 142.09, max: 348)
#
# Run: 179, exploration: 0.01, score: 202
# Scores: (min: 15, avg: 143.93, max: 348)
#
# Run: 180, exploration: 0.01, score: 220
# Scores: (min: 15, avg: 145.89, max: 348)
#
# Run: 181, exploration: 0.01, score: 172
# Scores: (min: 15, avg: 147.36, max: 348)
#
# Run: 182, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 148.83, max: 348)
#
# Run: 183, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 149.95, max: 348)
#
# Run: 184, exploration: 0.01, score: 462
# Scores: (min: 15, avg: 154.34, max: 462)
#
# Run: 185, exploration: 0.01, score: 210
# Scores: (min: 15, avg: 156.28, max: 462)
#
# Run: 186, exploration: 0.01, score: 197
# Scores: (min: 17, avg: 158.1, max: 462)
# Run: 187, exploration: 0.01, score: 162
# Scores: (min: 17, avg: 159.31, max: 462)
#
# Run: 188, exploration: 0.01, score: 141
# Scores: (min: 23, avg: 160.55, max: 462)
#
# Run: 189, exploration: 0.01, score: 193
# Scores: (min: 23, avg: 162.12, max: 462)
#
# Run: 190, exploration: 0.01, score: 127
# Scores: (min: 23, avg: 163.03, max: 462)
#
# Run: 191, exploration: 0.01, score: 178
# Scores: (min: 23, avg: 164.39, max: 462)
#
# Run: 192, exploration: 0.01, score: 288
# Scores: (min: 23, avg: 166.78, max: 462)
#
# Run: 193, exploration: 0.01, score: 157
# Scores: (min: 35, avg: 168.12, max: 462)
#
# Run: 194, exploration: 0.01, score: 172
# Scores: (min: 35, avg: 169.21, max: 462)
#
# Run: 195, exploration: 0.01, score: 149
# Scores: (min: 64, avg: 170.35, max: 462)
#
# Run: 196, exploration: 0.01, score: 131
# Scores: (min: 64, avg: 170.95, max: 462)
#
# Run: 197, exploration: 0.01, score: 359
# Scores: (min: 64, avg: 173.64, max: 462)
#
# Run: 198, exploration: 0.01, score: 170
# Scores: (min: 64, avg: 174.66, max: 462)
#
# Run: 199, exploration: 0.01, score: 378
# Scores: (min: 64, avg: 177.79, max: 462)
#
# Run: 200, exploration: 0.01, score: 151
# Scores: (min: 64, avg: 178.56, max: 462)
#
# Run: 201, exploration: 0.01, score: 257
# Scores: (min: 64, avg: 179.7, max: 462)
#
# Run: 202, exploration: 0.01, score: 178
# Scores: (min: 64, avg: 180.51, max: 462)
#
# Run: 203, exploration: 0.01, score: 200
# Scores: (min: 64, avg: 181.35, max: 462)
#
# Run: 204, exploration: 0.01, score: 176
# Scores: (min: 64, avg: 181.54, max: 462)
#
# Run: 205, exploration: 0.01, score: 144
# Scores: (min: 64, avg: 181.79, max: 462)
#
# Run: 206, exploration: 0.01, score: 161
# Scores: (min: 64, avg: 182.49, max: 462)
#
# Run: 207, exploration: 0.01, score: 207
# Scores: (min: 64, avg: 183.08, max: 462)
#
# Run: 208, exploration: 0.01, score: 126
# Scores: (min: 64, avg: 183.02, max: 462)
#
# Run: 209, exploration: 0.01, score: 163
# Scores: (min: 64, avg: 183.59, max: 462)
#
# Run: 210, exploration: 0.01, score: 156
# Scores: (min: 64, avg: 181.67, max: 462)
#
# Run: 211, exploration: 0.01, score: 144
# Scores: (min: 64, avg: 182.1, max: 462)
#
# Run: 212, exploration: 0.01, score: 166
# Scores: (min: 64, avg: 182.6, max: 462)
#
# Run: 213, exploration: 0.01, score: 159
# Scores: (min: 64, avg: 183.14, max: 462)
#
# Run: 214, exploration: 0.01, score: 72
# Scores: (min: 64, avg: 182.58, max: 462)
#
# Run: 215, exploration: 0.01, score: 162
# Scores: (min: 64, avg: 182.3, max: 462)
#
# Run: 216, exploration: 0.01, score: 208
# Scores: (min: 64, avg: 182.98, max: 462)
#
# Run: 217, exploration: 0.01, score: 162
# Scores: (min: 64, avg: 182.76, max: 462)
#
# Run: 218, exploration: 0.01, score: 206
# Scores: (min: 64, avg: 183.27, max: 462)
#
# Run: 219, exploration: 0.01, score: 230
# Scores: (min: 64, avg: 183.96, max: 462)
#
# Run: 220, exploration: 0.01, score: 112
# Scores: (min: 64, avg: 183.67, max: 462)
#
# Run: 221, exploration: 0.01, score: 97
# Scores: (min: 64, avg: 182.85, max: 462)
#
# Run: 222, exploration: 0.01, score: 176
# Scores: (min: 64, avg: 182.93, max: 462)
#
# Run: 223, exploration: 0.01, score: 231
# Scores: (min: 64, avg: 183.39, max: 462)
#
# Run: 224, exploration: 0.01, score: 100
# Scores: (min: 64, avg: 182.5, max: 462)
#
# Run: 225, exploration: 0.01, score: 163
# Scores: (min: 64, avg: 181.99, max: 462)
#
# Run: 226, exploration: 0.01, score: 163
# Scores: (min: 64, avg: 181.99, max: 462)
#
# Run: 227, exploration: 0.01, score: 215
# Scores: (min: 64, avg: 182.58, max: 462)
#
# Run: 228, exploration: 0.01, score: 233
# Scores: (min: 64, avg: 183.66, max: 462)
#
# Run: 229, exploration: 0.01, score: 125
# Scores: (min: 64, avg: 182.84, max: 462)
#
# Run: 230, exploration: 0.01, score: 171
# Scores: (min: 64, avg: 182.57, max: 462)
#
# Run: 231, exploration: 0.01, score: 153
# Scores: (min: 64, avg: 182.43, max: 462)
#
# Run: 232, exploration: 0.01, score: 198
# Scores: (min: 64, avg: 182.75, max: 462)
#
# Run: 233, exploration: 0.01, score: 500
# Scores: (min: 64, avg: 186.28, max: 500)
#
# Run: 234, exploration: 0.01, score: 218
# Scores: (min: 64, avg: 187.01, max: 500)
#
# Run: 235, exploration: 0.01, score: 223
# Scores: (min: 64, avg: 187.73, max: 500)
#
# Run: 236, exploration: 0.01, score: 256
# Scores: (min: 64, avg: 188.74, max: 500)
#
# Run: 237, exploration: 0.01, score: 167
# Scores: (min: 64, avg: 188.7, max: 500)
#
# Run: 238, exploration: 0.01, score: 392
# Scores: (min: 64, avg: 191.15, max: 500)
#
# Run: 239, exploration: 0.01, score: 201
# Scores: (min: 64, avg: 190.32, max: 500)
#
# Run: 240, exploration: 0.01, score: 108
# Scores: (min: 64, avg: 189.56, max: 500)
#
# Run: 241, exploration: 0.01, score: 159
# Scores: (min: 64, avg: 189.66, max: 500)
#
# Run: 242, exploration: 0.01, score: 223
# Scores: (min: 64, avg: 190.14, max: 500)
#
# Run: 243, exploration: 0.01, score: 206
# Scores: (min: 64, avg: 190.59, max: 500)
#
# Run: 244, exploration: 0.01, score: 218
# Scores: (min: 64, avg: 190.68, max: 500)
#
# Run: 245, exploration: 0.01, score: 189
# Scores: (min: 64, avg: 191.02, max: 500)
#
# Run: 246, exploration: 0.01, score: 236
# Scores: (min: 64, avg: 191.45, max: 500)
#
# Run: 247, exploration: 0.01, score: 191
# Scores: (min: 64, avg: 191.5, max: 500)
#
# Run: 248, exploration: 0.01, score: 263
# Scores: (min: 64, avg: 192.58, max: 500)
#
# Run: 249, exploration: 0.01, score: 314
# Scores: (min: 64, avg: 194.13, max: 500)
#
# Run: 250, exploration: 0.01, score: 270
# Scores: (min: 64, avg: 193.98, max: 500)
#
# Run: 251, exploration: 0.01, score: 171
# Scores: (min: 64, avg: 193.21, max: 500)
#
# Run: 252, exploration: 0.01, score: 144
# Scores: (min: 64, avg: 192.9, max: 500)
#
# Run: 253, exploration: 0.01, score: 161
# Scores: (min: 64, avg: 192.75, max: 500)
#
# Run: 254, exploration: 0.01, score: 139
# Scores: (min: 72, avg: 193.5, max: 500)
#
# Run: 255, exploration: 0.01, score: 187
# Scores: (min: 72, avg: 193.63, max: 500)
#
# Run: 256, exploration: 0.01, score: 143
# Scores: (min: 72, avg: 193.1, max: 500)
#
# Run: 257, exploration: 0.01, score: 256
# Scores: (min: 72, avg: 194.22, max: 500)
#
# Run: 258, exploration: 0.01, score: 158
# Scores: (min: 72, avg: 194.05, max: 500)
#
# Run: 259, exploration: 0.01, score: 207
# Scores: (min: 72, avg: 193.61, max: 500)
#
# Run: 260, exploration: 0.01, score: 153
# Scores: (min: 72, avg: 193.79, max: 500)
#
# Run: 261, exploration: 0.01, score: 193
# Scores: (min: 72, avg: 194.01, max: 500)
#
# Run: 262, exploration: 0.01, score: 153
# Scores: (min: 72, avg: 194.37, max: 500)
#
# Run: 263, exploration: 0.01, score: 263
# Scores: (min: 72, avg: 195.28, max: 500)
#
# Solved in 163 runs, 263 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-a5b32d071c94> in cartpole()
#      85             if terminal:
#      86                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 87                 score_logger.add_score(step, run)
#      88
#      89                 break
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
# Experiment 1: Modify Exploration Factor
EXPLORATION_DECAY = 0.9  # Slower decay to encourage more exploration

# Re-run the cartpole function with updated parameters
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.0984770902183612, score: 29
# Scores: (min: 13, avg: 21, max: 29)
#
# Run: 3, exploration: 0.042391158275216244, score: 9
# Scores: (min: 9, avg: 17, max: 29)
#
# Run: 4, exploration: 0.014780882941434608, score: 11
# Scores: (min: 9, avg: 15.5, max: 29)
#
# Run: 5, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14, max: 29)
#
# Run: 6, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.333333333333334, max: 29)
#
# Run: 7, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.285714285714286, max: 29)
#
# Run: 8, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.375, max: 29)
#
# Run: 9, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.22222222222222, max: 31)
#
# Run: 10, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.9, max: 31)
#
# Run: 11, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.363636363636363, max: 31)
#
# Run: 12, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.833333333333334, max: 31)
#
# Run: 13, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.538461538461538, max: 31)
#
# Run: 14, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 15.714285714285714, max: 31)
#
# Run: 15, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.4, max: 31)
#
# Run: 16, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.625, max: 31)
#
# Run: 17, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 17.470588235294116, max: 47)
#
# Run: 18, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.77777777777778, max: 47)
#
# Run: 19, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.36842105263158, max: 47)
#
# Run: 20, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.05, max: 47)
#
# Run: 21, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20, max: 47)
#
# Run: 22, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 21, max: 47)
#
# Run: 23, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 21.73913043478261, max: 47)
#
# Run: 24, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 22.541666666666668, max: 47)
#
# Run: 25, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 23.64, max: 50)
#
# Run: 26, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 25.153846153846153, max: 63)
#
# Run: 27, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 27.11111111111111, max: 78)
#
# Run: 28, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 28.392857142857142, max: 78)
#
# Run: 29, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 31.103448275862068, max: 107)
#
# Run: 30, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 34.7, max: 139)
#
# Run: 31, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 38.58064516129032, max: 155)
#
# Run: 32, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 42.4375, max: 162)
#
# Run: 33, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 48.42424242424242, max: 240)
#
# Run: 34, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 52.55882352941177, max: 240)
#
# Run: 35, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 56.02857142857143, max: 240)
#
# Run: 36, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 60.27777777777778, max: 240)
#
# Run: 37, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 63.16216216216216, max: 240)
#
# Run: 38, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 66.10526315789474, max: 240)
#
# Run: 39, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 69.97435897435898, max: 240)
#
# Run: 40, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 72.975, max: 240)
#
# Run: 41, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 75.02439024390245, max: 240)
#
# Run: 42, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 77.61904761904762, max: 240)
#
# Run: 43, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 79.86046511627907, max: 240)
#
# Run: 44, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 82.45454545454545, max: 240)
#
# Run: 45, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 84.84444444444445, max: 240)
#
# Run: 46, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 86.41304347826087, max: 240)
#
# Run: 47, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 88.85106382978724, max: 240)
#
# Run: 48, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 90.85416666666667, max: 240)
#
# Run: 49, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 92.38775510204081, max: 240)
#
# Run: 50, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 93.58, max: 240)
#
# Run: 51, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 95.03921568627452, max: 240)
#
# Run: 52, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 96.36538461538461, max: 240)
#
# Run: 53, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 97.18867924528301, max: 240)
#
# Run: 54, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 98.75925925925925, max: 240)
#
# Run: 55, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 100.27272727272727, max: 240)
#
# Run: 56, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 101.53571428571429, max: 240)
#
# Run: 57, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 102.35087719298245, max: 240)
#
# Run: 58, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 103.84482758620689, max: 240)
#
# Run: 59, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 104.96610169491525, max: 240)
#
# Run: 60, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 105.75, max: 240)
#
# Run: 61, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 106.93442622950819, max: 240)
#
# Run: 62, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 107.91935483870968, max: 240)
#
# Run: 63, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 109.87301587301587, max: 240)
#
# Run: 64, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 110.359375, max: 240)
#
# Run: 65, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 110.13846153846154, max: 240)
#
# Run: 66, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 110.0909090909091, max: 240)
#
# Run: 67, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 111.11940298507463, max: 240)
#
# Run: 68, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 112.57352941176471, max: 240)
#
# Run: 69, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 113.1159420289855, max: 240)
#
# Run: 70, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 113.24285714285715, max: 240)
#
# Run: 71, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 114.46478873239437, max: 240)
#
# Run: 72, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 114.88888888888889, max: 240)
#
# Run: 73, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 114.3972602739726, max: 240)
#
# Run: 74, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 115.02702702702703, max: 240)
#
# Run: 75, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 115.41333333333333, max: 240)
#
# Run: 76, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 116.75, max: 240)
#
# Run: 77, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 117.71428571428571, max: 240)
#
# Run: 78, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 118.38461538461539, max: 240)
#
# Run: 79, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 119.36708860759494, max: 240)
#
# Run: 80, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 118.025, max: 240)
#
# Run: 81, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 118.95061728395062, max: 240)
#
# Run: 82, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 119.91463414634147, max: 240)
#
# Run: 83, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 120.46987951807229, max: 240)
#
# Run: 84, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 121.53571428571429, max: 240)
#
# Run: 85, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 122.21176470588236, max: 240)
#
# Run: 86, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 122.98837209302326, max: 240)
#
# Run: 87, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 122.57471264367815, max: 240)
#
# Run: 88, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 122.42045454545455, max: 240)
#
# Run: 89, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 122.73033707865169, max: 240)
#
# Run: 90, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 123.11111111111111, max: 240)
#
# Run: 91, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 124.02197802197803, max: 240)
#
# Run: 92, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 124.78260869565217, max: 240)
#
# Run: 93, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 125.11827956989248, max: 240)
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 123.8936170212766, max: 240)
#
# Run: 95, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 124.22105263157894, max: 240)
#
# Run: 96, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 125.03125, max: 240)
#
# Run: 97, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 125.54639175257732, max: 240)
#
# Run: 98, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 126.37755102040816, max: 240)
#
# Run: 99, exploration: 0.01, score: 342
# Scores: (min: 8, avg: 128.55555555555554, max: 342)
#
# Run: 100, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 128.21, max: 342)
#
# Run: 101, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 128.45, max: 342)
#
# Run: 102, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 129.48, max: 342)
#
# Run: 103, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 129.59, max: 342)
#
# Run: 104, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 131.44, max: 342)
#
# Run: 105, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 133.16, max: 342)
#
# Run: 106, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 134.6, max: 342)
#
# Run: 107, exploration: 0.01, score: 254
# Scores: (min: 9, avg: 137.01, max: 342)
#
# Run: 108, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 138.69, max: 342)
#
# Run: 109, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 139.7, max: 342)
#
# Run: 110, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 141.11, max: 342)
#
# Run: 111, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 142.01, max: 342)
#
# Run: 112, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 144.08, max: 342)
#
# Run: 113, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 146.21, max: 342)
#
# Run: 114, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 147.85, max: 342)
#
# Run: 115, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 149.54, max: 342)
#
# Run: 116, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 150.26, max: 342)
#
# Run: 117, exploration: 0.01, score: 248
# Scores: (min: 10, avg: 152.27, max: 342)
#
# Run: 118, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 153.41, max: 342)
#
# Run: 119, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 154.87, max: 342)
#
# Run: 120, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 154.66, max: 342)
#
# Run: 121, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 155.41, max: 342)
#
# Run: 122, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 156.71, max: 342)
#
# Run: 123, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 158.2, max: 342)
#
# Run: 124, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 160.35, max: 342)
#
# Run: 125, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 161.02, max: 342)
#
# Run: 126, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 161.99, max: 342)
#
# Run: 127, exploration: 0.01, score: 292
# Scores: (min: 10, avg: 164.13, max: 342)
#
# Run: 128, exploration: 0.01, score: 290
# Scores: (min: 10, avg: 166.4, max: 342)
#
# Run: 129, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 167.29, max: 342)
#
# Run: 130, exploration: 0.01, score: 242
# Scores: (min: 10, avg: 168.32, max: 342)
#
# Run: 131, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 167.44, max: 342)
#
# Run: 132, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 165.91, max: 342)
#
# Run: 133, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 163.62, max: 342)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 161.83, max: 342)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 160.19, max: 342)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 158.2, max: 342)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 156.63, max: 342)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 154.97, max: 342)
#
# Run: 139, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 152.88, max: 342)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 151.07, max: 342)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 149.59, max: 342)
#
# Run: 142, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 147.84, max: 342)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.19, max: 342)
#
# Run: 144, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 144.36, max: 342)
#
# Run: 145, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 142.54, max: 342)
#
# Run: 146, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 141.08, max: 342)
#
# Run: 147, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 139.17, max: 342)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 137.41, max: 342)
#
# Run: 149, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 135.84, max: 342)
#
# Run: 150, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 134.41, max: 342)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 132.82, max: 342)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 131.28, max: 342)
#
# Run: 153, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 130.82, max: 342)
#
# Run: 154, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 130.25, max: 342)
#
# Run: 155, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 129.92, max: 342)
#
# Run: 156, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 128.56, max: 342)
#
# Run: 157, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 129.32, max: 342)
#
# Run: 158, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 127.94, max: 342)
#
# Run: 159, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 128.96, max: 342)
#
# Run: 160, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 129.01, max: 342)
#
# Run: 161, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 129.34, max: 342)
#
# Run: 162, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 132.66, max: 500)
#
# Run: 163, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 132.21, max: 500)
#
# Run: 164, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 132.9, max: 500)
#
# Run: 165, exploration: 0.01, score: 401
# Scores: (min: 8, avg: 135.95, max: 500)
#
# Run: 166, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 137.46, max: 500)
#
# Run: 167, exploration: 0.01, score: 440
# Scores: (min: 8, avg: 140.07, max: 500)
#
# Run: 168, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 138.45, max: 500)
#
# Run: 169, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 137.11, max: 500)
#
# Run: 170, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 135.99, max: 500)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 134.09, max: 500)
#
# Run: 172, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 134.23, max: 500)
#
# Run: 173, exploration: 0.01, score: 385
# Scores: (min: 8, avg: 137.29, max: 500)
#
# Run: 174, exploration: 0.01, score: 326
# Scores: (min: 8, avg: 138.94, max: 500)
#
# Run: 175, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 138.61, max: 500)
#
# Run: 176, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 138.94, max: 500)
#
# Run: 177, exploration: 0.01, score: 316
# Scores: (min: 8, avg: 140.19, max: 500)
#
# Run: 178, exploration: 0.01, score: 384
# Scores: (min: 8, avg: 142.33, max: 500)
#
# Run: 179, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 142.43, max: 500)
#
# Run: 180, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 144.6, max: 500)
#
# Run: 181, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 145.71, max: 500)
#
# Run: 182, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 145.5, max: 500)
#
# Run: 183, exploration: 0.01, score: 296
# Scores: (min: 8, avg: 146.8, max: 500)
#
# Run: 184, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 146.38, max: 500)
#
# Run: 185, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 147.59, max: 500)
#
# Run: 186, exploration: 0.01, score: 339
# Scores: (min: 8, avg: 149.09, max: 500)
#
# Run: 187, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 150.43, max: 500)
#
# Run: 188, exploration: 0.01, score: 379
# Scores: (min: 8, avg: 153.13, max: 500)
#
# Run: 189, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 153.44, max: 500)
#
# Run: 190, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 156.87, max: 500)
#
# Run: 191, exploration: 0.01, score: 378
# Scores: (min: 8, avg: 158.59, max: 500)
#
# Run: 192, exploration: 0.01, score: 360
# Scores: (min: 8, avg: 160.25, max: 500)
#
# Run: 193, exploration: 0.01, score: 301
# Scores: (min: 8, avg: 161.7, max: 500)
#
# Run: 194, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 163.06, max: 500)
# Run: 195, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 163.13, max: 500)
#
# Run: 196, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 161.63, max: 500)
#
# Run: 197, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 162.04, max: 500)
#
# Run: 198, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 162.91, max: 500)
#
# Run: 199, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 160.62, max: 500)
#
# Run: 200, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 160.7, max: 500)
#
# Run: 201, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 161.69, max: 500)
#
# Run: 202, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 162.9, max: 500)
#
# Run: 203, exploration: 0.01, score: 433
# Scores: (min: 8, avg: 167.03, max: 500)
#
# Run: 204, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 166.28, max: 500)
#
# Run: 205, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 166.13, max: 500)
#
# Run: 206, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 165.35, max: 500)
#
# Run: 207, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 164.44, max: 500)
#
# Run: 208, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 164.46, max: 500)
#
# Run: 209, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 164.41, max: 500)
#
# Run: 210, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 162.98, max: 500)
#
# Run: 211, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 162.09, max: 500)
#
# Run: 212, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 160.05, max: 500)
#
# Run: 213, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 157.92, max: 500)
#
# Run: 214, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 156.09, max: 500)
#
# Run: 215, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 154.63, max: 500)
#
# Run: 216, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 153.85, max: 500)
#
# Run: 217, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 151.6, max: 500)
#
# Run: 218, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 150.56, max: 500)
#
# Run: 219, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 149.06, max: 500)
#
# Run: 220, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 150.23, max: 500)
#
# Run: 221, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 151.11, max: 500)
#
# Run: 222, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 150.99, max: 500)
#
# Run: 223, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 154.12, max: 500)
#
# Run: 224, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 152.94, max: 500)
#
# Run: 225, exploration: 0.01, score: 458
# Scores: (min: 8, avg: 156.35, max: 500)
#
# Run: 226, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 156.04, max: 500)
#
# Run: 227, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 154.33, max: 500)
#
# Run: 228, exploration: 0.01, score: 324
# Scores: (min: 8, avg: 154.67, max: 500)
#
# Run: 229, exploration: 0.01, score: 358
# Scores: (min: 8, avg: 156.29, max: 500)
#
# Run: 230, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 155.57, max: 500)
#
# Run: 231, exploration: 0.01, score: 467
# Scores: (min: 8, avg: 159.57, max: 500)
#
# Run: 232, exploration: 0.01, score: 424
# Scores: (min: 8, avg: 163.72, max: 500)
#
# Run: 233, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 166.52, max: 500)
#
# Run: 234, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 168.06, max: 500)
#
# Run: 235, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 169.63, max: 500)
#
# Run: 236, exploration: 0.01, score: 330
# Scores: (min: 8, avg: 172.83, max: 500)
#
# Run: 237, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 174.1, max: 500)
#
# Run: 238, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 175.97, max: 500)
#
# Run: 239, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 177.33, max: 500)
#
# Run: 240, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 178.39, max: 500)
#
# Run: 241, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 179.46, max: 500)
#
# Run: 242, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 180.87, max: 500)
#
# Run: 243, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 182.57, max: 500)
#
# Run: 244, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 183.61, max: 500)
#
# Run: 245, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 185.11, max: 500)
#
# Run: 246, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 190, max: 500)
#
# Run: 247, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 191.6, max: 500)
#
# Run: 248, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 193, max: 500)
#
# Run: 249, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 195.27, max: 500)
#
# Solved in 149 runs, 249 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b19888f3fe7d> in <module>
#       3
#       4 # Re-run the cartpole function with updated parameters
# ----> 5 cartpole()
#
# <ipython-input-1-a5b32d071c94> in cartpole()
#      85             if terminal:
#      86                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 87                 score_logger.add_score(step, run)
#      88
#      89                 break
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
EXPLORATION_DECAY = 0.995  # Reset Param
# Experiment 2: Modify Discount Factor
GAMMA = 0.9  # Increase discount factor to prioritize long-term rewards

# Re-run the cartpole function with updated parameters
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.9416228069143757, score: 13
# Scores: (min: 13, avg: 16, max: 19)
#
# Run: 3, exploration: 0.7111635524897149, score: 57
# Scores: (min: 13, avg: 29.666666666666668, max: 57)
#
# Run: 4, exploration: 0.5590843898207511, score: 49
# Scores: (min: 13, avg: 34.5, max: 57)
#
# Run: 5, exploration: 0.5290920728090721, score: 12
# Scores: (min: 12, avg: 30, max: 57)
#
# Run: 6, exploration: 0.47862223409330756, score: 21
# Scores: (min: 12, avg: 28.5, max: 57)
#
# Run: 7, exploration: 0.45522245551230495, score: 11
# Scores: (min: 11, avg: 26, max: 57)
#
# Run: 8, exploration: 0.43732904629000013, score: 9
# Scores: (min: 9, avg: 23.875, max: 57)
#
# Run: 9, exploration: 0.4159480862733536, score: 11
# Scores: (min: 9, avg: 22.444444444444443, max: 57)
#
# Run: 10, exploration: 0.3976004408064698, score: 10
# Scores: (min: 9, avg: 21.2, max: 57)
#
# Run: 11, exploration: 0.37627099809304654, score: 12
# Scores: (min: 9, avg: 20.363636363636363, max: 57)
#
# Run: 12, exploration: 0.3578751580867638, score: 11
# Scores: (min: 9, avg: 19.583333333333332, max: 57)
#
# Run: 13, exploration: 0.3438081748424137, score: 9
# Scores: (min: 9, avg: 18.76923076923077, max: 57)
#
# Run: 14, exploration: 0.3302941218954743, score: 9
# Scores: (min: 9, avg: 18.071428571428573, max: 57)
#
# Run: 15, exploration: 0.3157247089126454, score: 10
# Scores: (min: 9, avg: 17.533333333333335, max: 57)
#
# Run: 16, exploration: 0.3033145315372582, score: 9
# Scores: (min: 9, avg: 17, max: 57)
#
# Run: 17, exploration: 0.2884855236625661, score: 11
# Scores: (min: 9, avg: 16.647058823529413, max: 57)
#
# Run: 18, exploration: 0.2757603055760701, score: 10
# Scores: (min: 9, avg: 16.27777777777778, max: 57)
#
# Run: 19, exploration: 0.2662522686041882, score: 8
# Scores: (min: 8, avg: 15.842105263157896, max: 57)
#
# Run: 20, exploration: 0.2519690537792925, score: 12
# Scores: (min: 8, avg: 15.65, max: 57)
#
# Run: 21, exploration: 0.2408545925762412, score: 10
# Scores: (min: 8, avg: 15.380952380952381, max: 57)
#
# Run: 22, exploration: 0.22793384675362674, score: 12
# Scores: (min: 8, avg: 15.227272727272727, max: 57)
#
# Run: 23, exploration: 0.192217783647157, score: 35
# Scores: (min: 8, avg: 16.08695652173913, max: 57)
#
# Run: 24, exploration: 0.17043057265153258, score: 25
# Scores: (min: 8, avg: 16.458333333333332, max: 57)
#
# Run: 25, exploration: 0.12936504510050365, score: 56
# Scores: (min: 8, avg: 18.04, max: 57)
#
# Run: 26, exploration: 0.089273984641318, score: 75
# Scores: (min: 8, avg: 20.23076923076923, max: 75)
#
# Run: 27, exploration: 0.0716045256805401, score: 45
# Scores: (min: 8, avg: 21.14814814814815, max: 75)
#
# Run: 28, exploration: 0.04966213277390804, score: 74
# Scores: (min: 8, avg: 23.035714285714285, max: 75)
#
# Run: 29, exploration: 0.032924408985721944, score: 83
# Scores: (min: 8, avg: 25.103448275862068, max: 83)
#
# Run: 30, exploration: 0.026673952849996664, score: 43
# Scores: (min: 8, avg: 25.7, max: 83)
#
# Run: 31, exploration: 0.016988875991640028, score: 91
# Scores: (min: 8, avg: 27.806451612903224, max: 91)
#
# Run: 32, exploration: 0.013289101019874787, score: 50
# Scores: (min: 8, avg: 28.5, max: 91)
#
# Run: 33, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 29.484848484848484, max: 91)
#
# Run: 34, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 31, max: 91)
#
# Run: 35, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 32.42857142857143, max: 91)
#
# Run: 36, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 34.52777777777778, max: 108)
#
# Run: 37, exploration: 0.01, score: 305
# Scores: (min: 8, avg: 41.83783783783784, max: 305)
#
# Run: 38, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 44.94736842105263, max: 305)
#
# Run: 39, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 47.51282051282051, max: 305)
#
# Run: 40, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 49.95, max: 305)
#
# Run: 41, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 55.02439024390244, max: 305)
#
# Run: 42, exploration: 0.01, score: 278
# Scores: (min: 8, avg: 60.333333333333336, max: 305)
#
# Run: 43, exploration: 0.01, score: 348
# Scores: (min: 8, avg: 67.02325581395348, max: 348)
#
# Run: 44, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 69.5, max: 348)
#
# Run: 45, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 72.24444444444444, max: 348)
#
# Run: 46, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 74.06521739130434, max: 348)
#
# Run: 47, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 76.53191489361703, max: 348)
#
# Run: 48, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 79.25, max: 348)
#
# Run: 49, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 81.51020408163265, max: 348)
#
# Run: 50, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 82.74, max: 348)
#
# Run: 51, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 85.29411764705883, max: 348)
#
# Run: 52, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 86.92307692307692, max: 348)
#
# Run: 53, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 90.24528301886792, max: 348)
#
# Run: 54, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 92.20370370370371, max: 348)
#
# Run: 55, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 94.07272727272728, max: 348)
#
# Run: 56, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 95.92857142857143, max: 348)
#
# Run: 57, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 97.29824561403508, max: 348)
#
# Run: 58, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 98.1896551724138, max: 348)
#
# Run: 59, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 99.89830508474576, max: 348)
#
# Run: 60, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 101.56666666666666, max: 348)
#
# Run: 61, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 102.62295081967213, max: 348)
#
# Run: 62, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 103.5, max: 348)
#
# Run: 63, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 104.73015873015873, max: 348)
#
# Run: 64, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 106.140625, max: 348)
#
# Run: 65, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 107.49230769230769, max: 348)
#
# Run: 66, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 108.77272727272727, max: 348)
#
# Run: 67, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 109.71641791044776, max: 348)
#
# Run: 68, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 110.72058823529412, max: 348)
#
# Run: 69, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 111.73913043478261, max: 348)
#
# Run: 70, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 113.2, max: 348)
#
# Run: 71, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 114.1830985915493, max: 348)
#
# Run: 72, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 115.04166666666667, max: 348)
#
# Run: 73, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 116.23287671232876, max: 348)
#
# Run: 74, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 116.82432432432432, max: 348)
#
# Run: 75, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 117.50666666666666, max: 348)
#
# Run: 76, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 117.98684210526316, max: 348)
#
# Run: 77, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 118.40259740259741, max: 348)
#
# Run: 78, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 119.75641025641026, max: 348)
#
# Run: 79, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 120.31645569620254, max: 348)
#
# Run: 80, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 120.675, max: 348)
#
# Run: 81, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 120.90123456790124, max: 348)
#
# Run: 82, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 121.54878048780488, max: 348)
#
# Run: 83, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 122.2289156626506, max: 348)
#
# Run: 84, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 122.71428571428571, max: 348)
#
# Run: 85, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 122.95294117647059, max: 348)
#
# Run: 86, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 123.20930232558139, max: 348)
#
# Run: 87, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 123.94252873563218, max: 348)
#
# Run: 88, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 124.44318181818181, max: 348)
#
# Run: 89, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 124.57303370786516, max: 348)
# Run: 90, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 125.11111111111111, max: 348)
#
# Run: 91, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 125.14285714285714, max: 348)
#
# Run: 92, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 125.3586956521739, max: 348)
#
# Run: 93, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 125.72043010752688, max: 348)
#
# Run: 94, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 126.41489361702128, max: 348)
#
# Run: 95, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 126.78947368421052, max: 348)
#
# Run: 96, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 127.14583333333333, max: 348)
#
# Run: 97, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 127.96907216494846, max: 348)
#
# Run: 98, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 128.1734693877551, max: 348)
#
# Run: 99, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 128.73737373737373, max: 348)
#
# Run: 100, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 129.11, max: 348)
#
# Run: 101, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 130.6, max: 348)
#
# Run: 102, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 132.61, max: 348)
#
# Run: 103, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 133.56, max: 348)
#
# Run: 104, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 134.63, max: 348)
#
# Run: 105, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 136.15, max: 348)
#
# Run: 106, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 137.28, max: 348)
#
# Run: 107, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 138.56, max: 348)
#
# Run: 108, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 139.43, max: 348)
#
# Run: 109, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 140.96, max: 348)
#
# Run: 110, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 143.24, max: 348)
#
# Run: 111, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 144.69, max: 348)
#
# Run: 112, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 146.41, max: 348)
#
# Run: 113, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 147.73, max: 348)
#
# Run: 114, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 147.85, max: 348)
#
# Run: 115, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 147.91, max: 348)
#
# Run: 116, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 148, max: 348)
#
# Run: 117, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 149.04, max: 348)
#
# Run: 118, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 150.31, max: 348)
#
# Run: 119, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 152.09, max: 348)
#
# Run: 120, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 153.77, max: 348)
#
# Run: 121, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 154.74, max: 348)
#
# Run: 122, exploration: 0.01, score: 170
# Scores: (min: 16, avg: 156.32, max: 348)
#
# Run: 123, exploration: 0.01, score: 151
# Scores: (min: 16, avg: 157.48, max: 348)
#
# Run: 124, exploration: 0.01, score: 122
# Scores: (min: 16, avg: 158.45, max: 348)
#
# Run: 125, exploration: 0.01, score: 161
# Scores: (min: 16, avg: 159.5, max: 348)
#
# Run: 126, exploration: 0.01, score: 124
# Scores: (min: 16, avg: 159.99, max: 348)
#
# Run: 127, exploration: 0.01, score: 152
# Scores: (min: 16, avg: 161.06, max: 348)
#
# Run: 128, exploration: 0.01, score: 187
# Scores: (min: 16, avg: 162.19, max: 348)
#
# Run: 129, exploration: 0.01, score: 114
# Scores: (min: 16, avg: 162.5, max: 348)
#
# Run: 130, exploration: 0.01, score: 166
# Scores: (min: 16, avg: 163.73, max: 348)
#
# Run: 131, exploration: 0.01, score: 188
# Scores: (min: 16, avg: 164.7, max: 348)
#
# Run: 132, exploration: 0.01, score: 119
# Scores: (min: 16, avg: 165.39, max: 348)
#
# Run: 133, exploration: 0.01, score: 152
# Scores: (min: 16, avg: 166.3, max: 348)
#
# Run: 134, exploration: 0.01, score: 275
# Scores: (min: 16, avg: 168.24, max: 348)
#
# Run: 135, exploration: 0.01, score: 151
# Scores: (min: 16, avg: 168.94, max: 348)
#
# Run: 136, exploration: 0.01, score: 191
# Scores: (min: 16, avg: 169.77, max: 348)
#
# Run: 137, exploration: 0.01, score: 123
# Scores: (min: 16, avg: 167.95, max: 348)
#
# Run: 138, exploration: 0.01, score: 123
# Scores: (min: 16, avg: 167.58, max: 348)
#
# Run: 139, exploration: 0.01, score: 163
# Scores: (min: 16, avg: 167.76, max: 348)
#
# Run: 140, exploration: 0.01, score: 188
# Scores: (min: 16, avg: 168.19, max: 348)
#
# Run: 141, exploration: 0.01, score: 166
# Scores: (min: 16, avg: 167.27, max: 348)
#
# Run: 142, exploration: 0.01, score: 152
# Scores: (min: 16, avg: 166.01, max: 348)
#
# Run: 143, exploration: 0.01, score: 178
# Scores: (min: 16, avg: 164.31, max: 275)
#
# Run: 144, exploration: 0.01, score: 110
# Scores: (min: 16, avg: 163.65, max: 275)
#
# Run: 145, exploration: 0.01, score: 88
# Scores: (min: 16, avg: 162.6, max: 275)
#
# Run: 146, exploration: 0.01, score: 220
# Scores: (min: 16, avg: 163.24, max: 275)
#
# Run: 147, exploration: 0.01, score: 173
# Scores: (min: 16, avg: 163.07, max: 275)
#
# Run: 148, exploration: 0.01, score: 14
# Scores: (min: 14, avg: 161.14, max: 275)
#
# Run: 149, exploration: 0.01, score: 137
# Scores: (min: 14, avg: 160.61, max: 275)
#
# Run: 150, exploration: 0.01, score: 179
# Scores: (min: 14, avg: 160.97, max: 275)
#
# Run: 151, exploration: 0.01, score: 194
# Scores: (min: 14, avg: 160.78, max: 275)
#
# Run: 152, exploration: 0.01, score: 163
# Scores: (min: 14, avg: 160.71, max: 275)
#
# Run: 153, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 159.48, max: 275)
#
# Run: 154, exploration: 0.01, score: 339
# Scores: (min: 14, avg: 160.91, max: 339)
#
# Run: 155, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 160.61, max: 339)
#
# Run: 156, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 160.35, max: 339)
#
# Run: 157, exploration: 0.01, score: 146
# Scores: (min: 14, avg: 160.07, max: 339)
#
# Run: 158, exploration: 0.01, score: 132
# Scores: (min: 14, avg: 159.9, max: 339)
#
# Run: 159, exploration: 0.01, score: 133
# Scores: (min: 14, avg: 159.24, max: 339)
#
# Run: 160, exploration: 0.01, score: 109
# Scores: (min: 14, avg: 158.33, max: 339)
#
# Run: 161, exploration: 0.01, score: 97
# Scores: (min: 14, avg: 157.64, max: 339)
#
# Run: 162, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 157.55, max: 339)
#
# Run: 163, exploration: 0.01, score: 132
# Scores: (min: 14, avg: 157.06, max: 339)
#
# Run: 164, exploration: 0.01, score: 142
# Scores: (min: 14, avg: 156.53, max: 339)
#
# Run: 165, exploration: 0.01, score: 179
# Scores: (min: 14, avg: 156.38, max: 339)
#
# Run: 166, exploration: 0.01, score: 199
# Scores: (min: 14, avg: 156.45, max: 339)
#
# Run: 167, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 156.29, max: 339)
#
# Run: 168, exploration: 0.01, score: 147
# Scores: (min: 14, avg: 155.98, max: 339)
#
# Run: 169, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 155.57, max: 339)
#
# Run: 170, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 155.02, max: 339)
#
# Run: 171, exploration: 0.01, score: 147
# Scores: (min: 14, avg: 154.66, max: 339)
#
# Run: 172, exploration: 0.01, score: 187
# Scores: (min: 14, avg: 154.77, max: 339)
#
# Run: 173, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 153.94, max: 339)
#
# Run: 174, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 154.26, max: 339)
#
# Run: 175, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 153.63, max: 339)
#
# Run: 176, exploration: 0.01, score: 189
# Scores: (min: 14, avg: 153.98, max: 339)
#
# Run: 177, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 154.04, max: 339)
#
# Run: 178, exploration: 0.01, score: 189
# Scores: (min: 14, avg: 153.69, max: 339)
#
# Run: 179, exploration: 0.01, score: 201
# Scores: (min: 14, avg: 154.06, max: 339)
#
# Run: 180, exploration: 0.01, score: 235
# Scores: (min: 14, avg: 154.92, max: 339)
#
# Run: 181, exploration: 0.01, score: 147
# Scores: (min: 14, avg: 155, max: 339)
#
# Run: 182, exploration: 0.01, score: 115
# Scores: (min: 14, avg: 154.41, max: 339)
#
# Run: 183, exploration: 0.01, score: 211
# Scores: (min: 14, avg: 154.74, max: 339)
#
# Run: 184, exploration: 0.01, score: 211
# Scores: (min: 14, avg: 155.22, max: 339)
#
# Run: 185, exploration: 0.01, score: 263
# Scores: (min: 14, avg: 156.42, max: 339)
#
# Run: 186, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 156.42, max: 339)
#
# Run: 187, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 155.95, max: 339)
#
# Run: 188, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 155.72, max: 339)
#
# Run: 189, exploration: 0.01, score: 233
# Scores: (min: 14, avg: 156.69, max: 339)
# Run: 190, exploration: 0.01, score: 114
# Scores: (min: 14, avg: 156.1, max: 339)
#
# Run: 191, exploration: 0.01, score: 225
# Scores: (min: 14, avg: 157.07, max: 339)
#
# Run: 192, exploration: 0.01, score: 106
# Scores: (min: 14, avg: 156.68, max: 339)
#
# Run: 193, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 156.77, max: 339)
#
# Run: 194, exploration: 0.01, score: 102
# Scores: (min: 14, avg: 155.88, max: 339)
#
# Run: 195, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 155.71, max: 339)
#
# Run: 196, exploration: 0.01, score: 111
# Scores: (min: 14, avg: 155.21, max: 339)
#
# Run: 197, exploration: 0.01, score: 199
# Scores: (min: 14, avg: 155.13, max: 339)
#
# Run: 198, exploration: 0.01, score: 201
# Scores: (min: 14, avg: 155.66, max: 339)
#
# Run: 199, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 155.54, max: 339)
#
# Run: 200, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 155.53, max: 339)
#
# Run: 201, exploration: 0.01, score: 41
# Scores: (min: 14, avg: 154.26, max: 339)
#
# Run: 202, exploration: 0.01, score: 29
# Scores: (min: 14, avg: 152.41, max: 339)
#
# Run: 203, exploration: 0.01, score: 107
# Scores: (min: 14, avg: 151.96, max: 339)
#
# Run: 204, exploration: 0.01, score: 191
# Scores: (min: 14, avg: 152.31, max: 339)
#
# Run: 205, exploration: 0.01, score: 203
# Scores: (min: 14, avg: 152.7, max: 339)
#
# Run: 206, exploration: 0.01, score: 78
# Scores: (min: 14, avg: 152.14, max: 339)
#
# Run: 207, exploration: 0.01, score: 102
# Scores: (min: 14, avg: 151.77, max: 339)
#
# Run: 208, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 152.53, max: 339)
#
# Run: 209, exploration: 0.01, score: 127
# Scores: (min: 14, avg: 152.16, max: 339)
#
# Run: 210, exploration: 0.01, score: 180
# Scores: (min: 14, avg: 151.58, max: 339)
#
# Run: 211, exploration: 0.01, score: 100
# Scores: (min: 14, avg: 151.01, max: 339)
#
# Run: 212, exploration: 0.01, score: 152
# Scores: (min: 14, avg: 150.7, max: 339)
#
# Run: 213, exploration: 0.01, score: 133
# Scores: (min: 14, avg: 150.62, max: 339)
#
# Run: 214, exploration: 0.01, score: 133
# Scores: (min: 14, avg: 151.74, max: 339)
#
# Run: 215, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 153.27, max: 339)
#
# Run: 216, exploration: 0.01, score: 63
# Scores: (min: 14, avg: 153.72, max: 339)
#
# Run: 217, exploration: 0.01, score: 94
# Scores: (min: 14, avg: 153.51, max: 339)
#
# Run: 218, exploration: 0.01, score: 160
# Scores: (min: 14, avg: 153.74, max: 339)
#
# Run: 219, exploration: 0.01, score: 108
# Scores: (min: 14, avg: 152.96, max: 339)
#
# Run: 220, exploration: 0.01, score: 217
# Scores: (min: 14, avg: 153.33, max: 339)
#
# Run: 221, exploration: 0.01, score: 86
# Scores: (min: 14, avg: 153.12, max: 339)
#
# Run: 222, exploration: 0.01, score: 36
# Scores: (min: 14, avg: 151.78, max: 339)
#
# Run: 223, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 151.46, max: 339)
#
# Run: 224, exploration: 0.01, score: 233
# Scores: (min: 14, avg: 152.57, max: 339)
#
# Run: 225, exploration: 0.01, score: 200
# Scores: (min: 14, avg: 152.96, max: 339)
#
# Run: 226, exploration: 0.01, score: 106
# Scores: (min: 14, avg: 152.78, max: 339)
#
# Run: 227, exploration: 0.01, score: 127
# Scores: (min: 14, avg: 152.53, max: 339)
#
# Run: 228, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 151.85, max: 339)
#
# Run: 229, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 152.29, max: 339)
#
# Run: 230, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 151.82, max: 339)
#
# Run: 231, exploration: 0.01, score: 111
# Scores: (min: 14, avg: 151.05, max: 339)
#
# Run: 232, exploration: 0.01, score: 109
# Scores: (min: 14, avg: 150.95, max: 339)
#
# Run: 233, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 150.91, max: 339)
#
# Run: 234, exploration: 0.01, score: 109
# Scores: (min: 14, avg: 149.25, max: 339)
#
# Run: 235, exploration: 0.01, score: 195
# Scores: (min: 14, avg: 149.69, max: 339)
#
# Run: 236, exploration: 0.01, score: 155
# Scores: (min: 14, avg: 149.33, max: 339)
#
# Run: 237, exploration: 0.01, score: 152
# Scores: (min: 14, avg: 149.62, max: 339)
#
# Run: 238, exploration: 0.01, score: 250
# Scores: (min: 14, avg: 150.89, max: 339)
#
# Run: 239, exploration: 0.01, score: 100
# Scores: (min: 14, avg: 150.26, max: 339)
#
# Run: 240, exploration: 0.01, score: 123
# Scores: (min: 14, avg: 149.61, max: 339)
#
# Run: 241, exploration: 0.01, score: 163
# Scores: (min: 14, avg: 149.58, max: 339)
#
# Run: 242, exploration: 0.01, score: 110
# Scores: (min: 14, avg: 149.16, max: 339)
#
# Run: 243, exploration: 0.01, score: 97
# Scores: (min: 14, avg: 148.35, max: 339)
#
# Run: 244, exploration: 0.01, score: 103
# Scores: (min: 14, avg: 148.28, max: 339)
#
# Run: 245, exploration: 0.01, score: 147
# Scores: (min: 14, avg: 148.87, max: 339)
#
# Run: 246, exploration: 0.01, score: 116
# Scores: (min: 14, avg: 147.83, max: 339)
#
# Run: 247, exploration: 0.01, score: 154
# Scores: (min: 14, avg: 147.64, max: 339)
#
# Run: 248, exploration: 0.01, score: 185
# Scores: (min: 29, avg: 149.35, max: 339)
#
# Run: 249, exploration: 0.01, score: 155
# Scores: (min: 29, avg: 149.53, max: 339)
#
# Run: 250, exploration: 0.01, score: 104
# Scores: (min: 29, avg: 148.78, max: 339)
#
# Run: 251, exploration: 0.01, score: 45
# Scores: (min: 29, avg: 147.29, max: 339)
#
# Run: 252, exploration: 0.01, score: 138
# Scores: (min: 29, avg: 147.04, max: 339)
#
# Run: 253, exploration: 0.01, score: 125
# Scores: (min: 29, avg: 146.89, max: 339)
#
# Run: 254, exploration: 0.01, score: 272
# Scores: (min: 29, avg: 146.22, max: 272)
#
# Run: 255, exploration: 0.01, score: 175
# Scores: (min: 29, avg: 146.32, max: 272)
#
# Run: 256, exploration: 0.01, score: 200
# Scores: (min: 29, avg: 146.6, max: 272)
#
# Run: 257, exploration: 0.01, score: 117
# Scores: (min: 29, avg: 146.31, max: 272)
#
# Run: 258, exploration: 0.01, score: 147
# Scores: (min: 29, avg: 146.46, max: 272)
#
# Run: 259, exploration: 0.01, score: 137
# Scores: (min: 29, avg: 146.5, max: 272)
#
# Run: 260, exploration: 0.01, score: 169
# Scores: (min: 29, avg: 147.1, max: 272)
#
# Run: 261, exploration: 0.01, score: 64
# Scores: (min: 29, avg: 146.77, max: 272)
#
# Run: 262, exploration: 0.01, score: 62
# Scores: (min: 29, avg: 145.91, max: 272)
#
# Run: 263, exploration: 0.01, score: 109
# Scores: (min: 29, avg: 145.68, max: 272)
#
# Run: 264, exploration: 0.01, score: 127
# Scores: (min: 29, avg: 145.53, max: 272)
#
# Run: 265, exploration: 0.01, score: 178
# Scores: (min: 29, avg: 145.52, max: 272)
#
# Run: 266, exploration: 0.01, score: 265
# Scores: (min: 29, avg: 146.18, max: 272)
#
# Run: 267, exploration: 0.01, score: 148
# Scores: (min: 29, avg: 146.1, max: 272)
#
# Run: 268, exploration: 0.01, score: 132
# Scores: (min: 29, avg: 145.95, max: 272)
#
# Run: 269, exploration: 0.01, score: 134
# Scores: (min: 29, avg: 145.89, max: 272)
#
# Run: 270, exploration: 0.01, score: 115
# Scores: (min: 29, avg: 145.45, max: 272)
#
# Run: 271, exploration: 0.01, score: 138
# Scores: (min: 29, avg: 145.36, max: 272)
#
# Run: 272, exploration: 0.01, score: 26
# Scores: (min: 26, avg: 143.75, max: 272)
#
# Run: 273, exploration: 0.01, score: 131
# Scores: (min: 26, avg: 143.87, max: 272)
#
# Run: 274, exploration: 0.01, score: 187
# Scores: (min: 26, avg: 143.82, max: 272)
#
# Run: 275, exploration: 0.01, score: 144
# Scores: (min: 26, avg: 144.21, max: 272)
#
# Run: 276, exploration: 0.01, score: 291
# Scores: (min: 26, avg: 145.23, max: 291)
#
# Run: 277, exploration: 0.01, score: 158
# Scores: (min: 26, avg: 145.25, max: 291)
#
# Run: 278, exploration: 0.01, score: 149
# Scores: (min: 26, avg: 144.85, max: 291)
#
# Run: 279, exploration: 0.01, score: 210
# Scores: (min: 26, avg: 144.94, max: 291)
#
# Run: 280, exploration: 0.01, score: 165
# Scores: (min: 26, avg: 144.24, max: 291)
#
# Run: 281, exploration: 0.01, score: 119
# Scores: (min: 26, avg: 143.96, max: 291)
#
# Run: 282, exploration: 0.01, score: 44
# Scores: (min: 26, avg: 143.25, max: 291)
#
# Run: 283, exploration: 0.01, score: 122
# Scores: (min: 26, avg: 142.36, max: 291)
#
# Run: 284, exploration: 0.01, score: 171
# Scores: (min: 26, avg: 141.96, max: 291)
#
# Run: 285, exploration: 0.01, score: 169
# Scores: (min: 26, avg: 141.02, max: 291)
#
# Run: 286, exploration: 0.01, score: 231
# Scores: (min: 26, avg: 141.88, max: 291)
#
# Run: 287, exploration: 0.01, score: 240
# Scores: (min: 26, avg: 142.88, max: 291)
#
# Run: 288, exploration: 0.01, score: 219
# Scores: (min: 26, avg: 143.62, max: 291)
#
# Run: 289, exploration: 0.01, score: 278
# Scores: (min: 26, avg: 144.07, max: 291)
#
# Run: 290, exploration: 0.01, score: 142
# Scores: (min: 26, avg: 144.35, max: 291)
# Run: 291, exploration: 0.01, score: 179
# Scores: (min: 26, avg: 143.89, max: 291)
#
# Run: 292, exploration: 0.01, score: 136
# Scores: (min: 26, avg: 144.19, max: 291)
#
# Run: 293, exploration: 0.01, score: 167
# Scores: (min: 26, avg: 144.18, max: 291)
#
# Run: 294, exploration: 0.01, score: 57
# Scores: (min: 26, avg: 143.73, max: 291)
#
# Run: 295, exploration: 0.01, score: 82
# Scores: (min: 26, avg: 143.1, max: 291)
#
# Run: 296, exploration: 0.01, score: 134
# Scores: (min: 26, avg: 143.33, max: 291)
#
# Run: 297, exploration: 0.01, score: 122
# Scores: (min: 26, avg: 142.56, max: 291)
#
# Run: 298, exploration: 0.01, score: 153
# Scores: (min: 26, avg: 142.08, max: 291)
#
# Run: 299, exploration: 0.01, score: 20
# Scores: (min: 20, avg: 140.56, max: 291)
#
# Run: 300, exploration: 0.01, score: 241
# Scores: (min: 20, avg: 141.32, max: 291)
#
# Run: 301, exploration: 0.01, score: 265
# Scores: (min: 20, avg: 143.56, max: 291)
#
# Run: 302, exploration: 0.01, score: 105
# Scores: (min: 20, avg: 144.32, max: 291)
#
# Run: 303, exploration: 0.01, score: 105
# Scores: (min: 20, avg: 144.3, max: 291)
#
# Run: 304, exploration: 0.01, score: 200
# Scores: (min: 20, avg: 144.39, max: 291)
#
# Run: 305, exploration: 0.01, score: 208
# Scores: (min: 20, avg: 144.44, max: 291)
#
# Run: 306, exploration: 0.01, score: 110
# Scores: (min: 20, avg: 144.76, max: 291)
#
# Run: 307, exploration: 0.01, score: 125
# Scores: (min: 20, avg: 144.99, max: 291)
#
# Run: 308, exploration: 0.01, score: 191
# Scores: (min: 20, avg: 145.18, max: 291)
#
# Run: 309, exploration: 0.01, score: 186
# Scores: (min: 20, avg: 145.77, max: 291)
#
# Run: 310, exploration: 0.01, score: 172
# Scores: (min: 20, avg: 145.69, max: 291)
#
# Run: 311, exploration: 0.01, score: 165
# Scores: (min: 20, avg: 146.34, max: 291)
#
# Run: 312, exploration: 0.01, score: 101
# Scores: (min: 20, avg: 145.83, max: 291)
#
# Run: 313, exploration: 0.01, score: 133
# Scores: (min: 20, avg: 145.83, max: 291)
#
# Run: 314, exploration: 0.01, score: 291
# Scores: (min: 20, avg: 147.41, max: 291)
#
# Run: 315, exploration: 0.01, score: 259
# Scores: (min: 20, avg: 148.31, max: 291)
#
# Run: 316, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 152.68, max: 500)
#
# Run: 317, exploration: 0.01, score: 155
# Scores: (min: 20, avg: 153.29, max: 500)
#
# Run: 318, exploration: 0.01, score: 351
# Scores: (min: 20, avg: 155.2, max: 500)
#
# Run: 319, exploration: 0.01, score: 399
# Scores: (min: 20, avg: 158.11, max: 500)
#
# Run: 320, exploration: 0.01, score: 121
# Scores: (min: 20, avg: 157.15, max: 500)
#
# Run: 321, exploration: 0.01, score: 127
# Scores: (min: 20, avg: 157.56, max: 500)
#
# Run: 322, exploration: 0.01, score: 435
# Scores: (min: 20, avg: 161.55, max: 500)
#
# Run: 323, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 165.36, max: 500)
#
# Run: 324, exploration: 0.01, score: 130
# Scores: (min: 20, avg: 164.33, max: 500)
#
# Run: 325, exploration: 0.01, score: 177
# Scores: (min: 20, avg: 164.1, max: 500)
#
# Run: 326, exploration: 0.01, score: 324
# Scores: (min: 20, avg: 166.28, max: 500)
#
# Run: 327, exploration: 0.01, score: 278
# Scores: (min: 20, avg: 167.79, max: 500)
#
# Run: 328, exploration: 0.01, score: 136
# Scores: (min: 20, avg: 167.96, max: 500)
#
# Run: 329, exploration: 0.01, score: 131
# Scores: (min: 20, avg: 167.69, max: 500)
#
# Run: 330, exploration: 0.01, score: 97
# Scores: (min: 20, avg: 167.47, max: 500)
#
# Run: 331, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 171.36, max: 500)
#
# Run: 332, exploration: 0.01, score: 140
# Scores: (min: 20, avg: 171.67, max: 500)
#
# Run: 333, exploration: 0.01, score: 187
# Scores: (min: 20, avg: 172.06, max: 500)
#
# Run: 334, exploration: 0.01, score: 451
# Scores: (min: 20, avg: 175.48, max: 500)
#
# Run: 335, exploration: 0.01, score: 136
# Scores: (min: 20, avg: 174.89, max: 500)
#
# Run: 336, exploration: 0.01, score: 92
# Scores: (min: 20, avg: 174.26, max: 500)
#
# Run: 337, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 177.74, max: 500)
#
# Run: 338, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 180.24, max: 500)
#
# Run: 339, exploration: 0.01, score: 117
# Scores: (min: 20, avg: 180.41, max: 500)
#
# Run: 340, exploration: 0.01, score: 269
# Scores: (min: 20, avg: 181.87, max: 500)
#
# Run: 341, exploration: 0.01, score: 343
# Scores: (min: 20, avg: 183.67, max: 500)
#
# Run: 342, exploration: 0.01, score: 309
# Scores: (min: 20, avg: 185.66, max: 500)
#
# Run: 343, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 184.85, max: 500)
#
# Run: 344, exploration: 0.01, score: 19
# Scores: (min: 16, avg: 184.01, max: 500)
#
# Run: 345, exploration: 0.01, score: 162
# Scores: (min: 16, avg: 184.16, max: 500)
#
# Run: 346, exploration: 0.01, score: 124
# Scores: (min: 16, avg: 184.24, max: 500)
#
# Run: 347, exploration: 0.01, score: 26
# Scores: (min: 16, avg: 182.96, max: 500)
#
# Run: 348, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 181.23, max: 500)
#
# Run: 349, exploration: 0.01, score: 420
# Scores: (min: 12, avg: 183.88, max: 500)
#
# Run: 350, exploration: 0.01, score: 88
# Scores: (min: 12, avg: 183.72, max: 500)
#
# Run: 351, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 183.39, max: 500)
#
# Run: 352, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 184.01, max: 500)
#
# Run: 353, exploration: 0.01, score: 369
# Scores: (min: 12, avg: 186.45, max: 500)
#
# Run: 354, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 185.01, max: 500)
#
# Run: 355, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 184.17, max: 500)
#
# Run: 356, exploration: 0.01, score: 308
# Scores: (min: 12, avg: 185.25, max: 500)
#
# Run: 357, exploration: 0.01, score: 478
# Scores: (min: 12, avg: 188.86, max: 500)
#
# Run: 358, exploration: 0.01, score: 324
# Scores: (min: 12, avg: 190.63, max: 500)
#
# Run: 359, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 190.68, max: 500)
#
# Run: 360, exploration: 0.01, score: 82
# Scores: (min: 12, avg: 189.81, max: 500)
#
# Run: 361, exploration: 0.01, score: 43
# Scores: (min: 12, avg: 189.6, max: 500)
#
# Run: 362, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 189.89, max: 500)
#
# Run: 363, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 189.83, max: 500)
#
# Run: 364, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 188.69, max: 500)
#
# Run: 365, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 187.02, max: 500)
#
# Run: 366, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 185.48, max: 500)
#
# Run: 367, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 185.51, max: 500)
#
# Run: 368, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 184.98, max: 500)
#
# Run: 369, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 184.87, max: 500)
#
# Run: 370, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 186.08, max: 500)
#
# Run: 371, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 185.08, max: 500)
#
# Run: 372, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 184.94, max: 500)
#
# Run: 373, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 183.76, max: 500)
#
# Run: 374, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 183.12, max: 500)
#
# Run: 375, exploration: 0.01, score: 203
# Scores: (min: 11, avg: 183.71, max: 500)
#
# Run: 376, exploration: 0.01, score: 387
# Scores: (min: 11, avg: 184.67, max: 500)
#
# Run: 377, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 184.65, max: 500)
#
# Run: 378, exploration: 0.01, score: 390
# Scores: (min: 11, avg: 187.06, max: 500)
#
# Run: 379, exploration: 0.01, score: 477
# Scores: (min: 11, avg: 189.73, max: 500)
#
# Run: 380, exploration: 0.01, score: 246
# Scores: (min: 11, avg: 190.54, max: 500)
#
# Run: 381, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 190.77, max: 500)
#
# Run: 382, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 191.52, max: 500)
#
# Run: 383, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 192.59, max: 500)
#
# Run: 384, exploration: 0.01, score: 173
# Scores: (min: 11, avg: 192.61, max: 500)
#
# Run: 385, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 192.38, max: 500)
#
# Run: 386, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 190.99, max: 500)
#
# Run: 387, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 190.41, max: 500)
#
# Run: 388, exploration: 0.01, score: 226
# Scores: (min: 11, avg: 190.48, max: 500)
#
# Run: 389, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 189.99, max: 500)
#
# Run: 390, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 189.5, max: 500)
#
# Run: 391, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 188.72, max: 500)
# Run: 392, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 188.4, max: 500)
#
# Run: 393, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 187.97, max: 500)
#
# Run: 394, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 188.88, max: 500)
#
# Run: 395, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 188.79, max: 500)
#
# Run: 396, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 188.47, max: 500)
#
# Run: 397, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 188.9, max: 500)
#
# Run: 398, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 188.31, max: 500)
#
# Run: 399, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 189.52, max: 500)
#
# Run: 400, exploration: 0.01, score: 348
# Scores: (min: 11, avg: 190.59, max: 500)
#
# Run: 401, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 188.89, max: 500)
#
# Run: 402, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 188.84, max: 500)
#
# Run: 403, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 187.95, max: 500)
#
# Run: 404, exploration: 0.01, score: 279
# Scores: (min: 11, avg: 188.74, max: 500)
#
# Run: 405, exploration: 0.01, score: 211
# Scores: (min: 11, avg: 188.77, max: 500)
#
# Run: 406, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 189.29, max: 500)
#
# Run: 407, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 189.01, max: 500)
#
# Run: 408, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 188.81, max: 500)
#
# Run: 409, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 187.87, max: 500)
#
# Run: 410, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 186.3, max: 500)
#
# Run: 411, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 185.22, max: 500)
#
# Run: 412, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 184.31, max: 500)
#
# Run: 413, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 183.51, max: 500)
#
# Run: 414, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 181.18, max: 500)
#
# Run: 415, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 179.61, max: 500)
#
# Run: 416, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 175.85, max: 500)
#
# Run: 417, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 176.57, max: 500)
#
# Run: 418, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 175.16, max: 500)
#
# Run: 419, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 172.91, max: 500)
#
# Run: 420, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 173.49, max: 500)
#
# Run: 421, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 173.37, max: 500)
#
# Run: 422, exploration: 0.01, score: 339
# Scores: (min: 10, avg: 172.41, max: 500)
#
# Run: 423, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 167.55, max: 500)
#
# Run: 424, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 167.21, max: 500)
#
# Run: 425, exploration: 0.01, score: 277
# Scores: (min: 10, avg: 168.21, max: 500)
#
# Run: 426, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 167.52, max: 500)
#
# Run: 427, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 166.84, max: 500)
#
# Run: 428, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 165.59, max: 500)
#
# Run: 429, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 169.28, max: 500)
#
# Run: 430, exploration: 0.01, score: 331
# Scores: (min: 10, avg: 171.62, max: 500)
#
# Run: 431, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 167.72, max: 500)
#
# Run: 432, exploration: 0.01, score: 337
# Scores: (min: 10, avg: 169.69, max: 500)
#
# Run: 433, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 168.93, max: 500)
#
# Run: 434, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 169.42, max: 500)
#
# Run: 435, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 169.25, max: 500)
#
# Run: 436, exploration: 0.01, score: 389
# Scores: (min: 10, avg: 172.22, max: 500)
#
# Run: 437, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 168.86, max: 500)
#
# Run: 438, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 164.98, max: 500)
#
# Run: 439, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 165.93, max: 500)
#
# Run: 440, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 163.95, max: 500)
#
# Run: 441, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 160.94, max: 500)
#
# Run: 442, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 157.96, max: 500)
#
# Run: 443, exploration: 0.01, score: 233
# Scores: (min: 10, avg: 160.13, max: 500)
#
# Run: 444, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 161.69, max: 500)
#
# Run: 445, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 161.97, max: 500)
#
# Run: 446, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 160.92, max: 500)
#
# Run: 447, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 161.05, max: 500)
#
# Run: 448, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 161.13, max: 500)
#
# Run: 449, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 157.92, max: 500)
#
# Run: 450, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 159.13, max: 500)
#
# Run: 451, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 164.01, max: 500)
#
# Run: 452, exploration: 0.01, score: 252
# Scores: (min: 10, avg: 164.53, max: 500)
#
# Run: 453, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 162.33, max: 500)
#
# Run: 454, exploration: 0.01, score: 208
# Scores: (min: 10, avg: 163.13, max: 500)
#
# Run: 455, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 163.17, max: 500)
#
# Run: 456, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 161.82, max: 500)
#
# Run: 457, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 157.16, max: 500)
#
# Run: 458, exploration: 0.01, score: 232
# Scores: (min: 10, avg: 156.24, max: 500)
#
# Run: 459, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 156.17, max: 500)
#
# Run: 460, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 156.51, max: 500)
#
# Run: 461, exploration: 0.01, score: 391
# Scores: (min: 10, avg: 159.99, max: 500)
#
# Run: 462, exploration: 0.01, score: 232
# Scores: (min: 10, avg: 161.4, max: 500)
#
# Run: 463, exploration: 0.01, score: 290
# Scores: (min: 10, avg: 163.27, max: 500)
#
# Run: 464, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 164.06, max: 500)
#
# Run: 465, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 165.19, max: 500)
#
# Run: 466, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 165.12, max: 500)
#
# Run: 467, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 165.01, max: 500)
#
# Run: 468, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 165.51, max: 500)
#
# Run: 469, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 166.07, max: 500)
#
# Run: 470, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 168.71, max: 500)
#
# Run: 471, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 169.93, max: 500)
#
# Run: 472, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 171.18, max: 500)
#
# Run: 473, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 173.04, max: 500)
#
# Run: 474, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 172.73, max: 500)
#
# Run: 475, exploration: 0.01, score: 411
# Scores: (min: 10, avg: 174.81, max: 500)
#
# Run: 476, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 171.98, max: 500)
#
# Run: 477, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 171.74, max: 500)
#
# Run: 478, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 169.22, max: 500)
#
# Run: 479, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 166.3, max: 500)
#
# Run: 480, exploration: 0.01, score: 203
# Scores: (min: 10, avg: 165.87, max: 500)
#
# Run: 481, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 165.97, max: 500)
#
# Run: 482, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 164.9, max: 500)
#
# Run: 483, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 162.79, max: 500)
#
# Run: 484, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 161.34, max: 500)
#
# Run: 485, exploration: 0.01, score: 307
# Scores: (min: 10, avg: 162.95, max: 500)
#
# Run: 486, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 163.4, max: 500)
#
# Run: 487, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 162.76, max: 500)
#
# Run: 488, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 161.92, max: 500)
#
# Run: 489, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 161.44, max: 500)
#
# Run: 490, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 162.18, max: 500)
#
# Run: 491, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 161.81, max: 500)
#
# Run: 492, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 162.79, max: 500)
# Run: 493, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 163.14, max: 500)
#
# Run: 494, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 162.86, max: 500)
#
# Run: 495, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 163.29, max: 500)
#
# Run: 496, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 163.49, max: 500)
#
# Run: 497, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 163.35, max: 500)
#
# Run: 498, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 163.44, max: 500)
#
# Run: 499, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 163.36, max: 500)
#
# Run: 500, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 161.68, max: 500)
#
# Run: 501, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 162.16, max: 500)
#
# Run: 502, exploration: 0.01, score: 200
# Scores: (min: 10, avg: 163.16, max: 500)
#
# Run: 503, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 164.29, max: 500)
#
# Run: 504, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 162.09, max: 500)
#
# Run: 505, exploration: 0.01, score: 280
# Scores: (min: 10, avg: 162.78, max: 500)
#
# Run: 506, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 163.3, max: 500)
#
# Run: 507, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 163.7, max: 500)
#
# Run: 508, exploration: 0.01, score: 327
# Scores: (min: 10, avg: 165.26, max: 500)
#
# Run: 509, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 164.75, max: 500)
#
# Run: 510, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 164.85, max: 500)
#
# Run: 511, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 164.54, max: 500)
#
# Run: 512, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 164.57, max: 500)
#
# Run: 513, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 164.96, max: 500)
#
# Run: 514, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 165.82, max: 500)
#
# Run: 515, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 165.15, max: 500)
#
# Run: 516, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 165.61, max: 500)
#
# Run: 517, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 164.36, max: 500)
#
# Run: 518, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 164.91, max: 500)
#
# Run: 519, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 164.42, max: 500)
#
# Run: 520, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 163.61, max: 500)
#
# Run: 521, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 163.51, max: 500)
#
# Run: 522, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 161.21, max: 500)
#
# Run: 523, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 163.44, max: 500)
#
# Run: 524, exploration: 0.01, score: 173
# Scores: (min: 11, avg: 164.21, max: 500)
#
# Run: 525, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 162.7, max: 500)
#
# Run: 526, exploration: 0.01, score: 66
# Scores: (min: 11, avg: 160.81, max: 500)
#
# Run: 527, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 160.12, max: 500)
#
# Run: 528, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 161.54, max: 500)
#
# Run: 529, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 157.78, max: 500)
#
# Run: 530, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 155.62, max: 500)
#
# Run: 531, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 155.62, max: 500)
#
# Run: 532, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 152.68, max: 500)
#
# Run: 533, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 152.88, max: 500)
#
# Run: 534, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 149.92, max: 500)
#
# Run: 535, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 149.95, max: 500)
#
# Run: 536, exploration: 0.01, score: 208
# Scores: (min: 11, avg: 148.14, max: 500)
#
# Run: 537, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 148.77, max: 500)
#
# Run: 538, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 148.64, max: 500)
#
# Run: 539, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 146.98, max: 500)
#
# Run: 540, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 146.37, max: 500)
#
# Run: 541, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 146.98, max: 500)
#
# Run: 542, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 148.38, max: 500)
#
# Run: 543, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 147.4, max: 500)
#
# Run: 544, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 146.71, max: 500)
#
# Run: 545, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 145.62, max: 500)
#
# Run: 546, exploration: 0.01, score: 228
# Scores: (min: 10, avg: 147.71, max: 500)
#
# Run: 547, exploration: 0.01, score: 279
# Scores: (min: 10, avg: 150.11, max: 500)
#
# Run: 548, exploration: 0.01, score: 204
# Scores: (min: 10, avg: 151.95, max: 500)
#
# Run: 549, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 151.31, max: 500)
#
# Run: 550, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 149.46, max: 500)
#
# Run: 551, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 144.6, max: 500)
#
# Run: 552, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 142.2, max: 500)
#
# Run: 553, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 141.13, max: 500)
#
# Run: 554, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 139.21, max: 500)
#
# Run: 555, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 138.38, max: 500)
#
# Run: 556, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 137.02, max: 500)
#
# Run: 557, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 137.08, max: 500)
#
# Run: 558, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 134.88, max: 500)
#
# Run: 559, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 133.69, max: 500)
#
# Run: 560, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 132.69, max: 500)
#
# Run: 561, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 128.91, max: 500)
#
# Run: 562, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 126.76, max: 500)
#
# Run: 563, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 124.02, max: 500)
#
# Run: 564, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 123.2, max: 500)
#
# Run: 565, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 122.38, max: 500)
#
# Run: 566, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 122.89, max: 500)
#
# Run: 567, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 122.6, max: 500)
#
# Run: 568, exploration: 0.01, score: 384
# Scores: (min: 10, avg: 125.15, max: 500)
#
# Run: 569, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 124.78, max: 500)
#
# Run: 570, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 121.61, max: 411)
#
# Run: 571, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 120.17, max: 411)
#
# Run: 572, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 120.51, max: 411)
#
# Run: 573, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 120.3, max: 411)
#
# Run: 574, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 119.55, max: 411)
#
# Run: 575, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 117.18, max: 384)
#
# Run: 576, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 117.63, max: 384)
#
# Run: 577, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 121.31, max: 500)
#
# Run: 578, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 121.31, max: 500)
#
# Run: 579, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 121.37, max: 500)
#
# Run: 580, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 120.47, max: 500)
#
# Run: 581, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 123.95, max: 500)
#
# Run: 582, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 124.2, max: 500)
#
# Run: 583, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 124.22, max: 500)
#
# Run: 584, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 125.84, max: 500)
#
# Run: 585, exploration: 0.01, score: 82
# Scores: (min: 10, avg: 123.59, max: 500)
#
# Run: 586, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 122.35, max: 500)
#
# Run: 587, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 122.71, max: 500)
#
# Run: 588, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 122.43, max: 500)
#
# Run: 589, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 122.71, max: 500)
#
# Run: 590, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 122.24, max: 500)
#
# Run: 591, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 122.57, max: 500)
#
# Run: 592, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 121.53, max: 500)
#
# Run: 593, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 120.93, max: 500)
# Run: 594, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 120.7, max: 500)
#
# Run: 595, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 121.9, max: 500)
#
# Run: 596, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 122, max: 500)
#
# Run: 597, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 121.51, max: 500)
#
# Run: 598, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 121.55, max: 500)
#
# Run: 599, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 121.19, max: 500)
#
# Run: 600, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 120.91, max: 500)
#
# Run: 601, exploration: 0.01, score: 269
# Scores: (min: 10, avg: 122.17, max: 500)
#
# Run: 602, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 120.28, max: 500)
#
# Run: 603, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 119.13, max: 500)
#
# Run: 604, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 118.67, max: 500)
#
# Run: 605, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 117.49, max: 500)
#
# Run: 606, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 116.44, max: 500)
#
# Run: 607, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 116.25, max: 500)
#
# Run: 608, exploration: 0.01, score: 294
# Scores: (min: 10, avg: 115.92, max: 500)
#
# Run: 609, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 116.71, max: 500)
#
# Run: 610, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 118.25, max: 500)
#
# Run: 611, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 119.12, max: 500)
#
# Run: 612, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 119.99, max: 500)
#
# Run: 613, exploration: 0.01, score: 365
# Scores: (min: 10, avg: 122.72, max: 500)
#
# Run: 614, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 122.22, max: 500)
#
# Run: 615, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 122.68, max: 500)
#
# Run: 616, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 122.49, max: 500)
#
# Run: 617, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 122.68, max: 500)
#
# Run: 618, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 121.12, max: 500)
#
# Run: 619, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 121.16, max: 500)
#
# Run: 620, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 121.49, max: 500)
#
# Run: 621, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 121.91, max: 500)
#
# Run: 622, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 121.99, max: 500)
#
# Run: 623, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 121.29, max: 500)
#
# Run: 624, exploration: 0.01, score: 309
# Scores: (min: 10, avg: 122.65, max: 500)
#
# Run: 625, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 123.22, max: 500)
#
# Run: 626, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 123.79, max: 500)
#
# Run: 627, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 122.49, max: 500)
#
# Run: 628, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 121.92, max: 500)
#
# Run: 629, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 121.85, max: 500)
#
# Run: 630, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 121.73, max: 500)
#
# Run: 631, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 121.71, max: 500)
#
# Run: 632, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 123.17, max: 500)
#
# Run: 633, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 122.88, max: 500)
#
# Run: 634, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 121.94, max: 500)
#
# Run: 635, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 121.49, max: 500)
#
# Run: 636, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 120.6, max: 500)
#
# Run: 637, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 119.83, max: 500)
#
# Run: 638, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 120.23, max: 500)
#
# Run: 639, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 121.02, max: 500)
#
# Run: 640, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 122.38, max: 500)
#
# Run: 641, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 123.2, max: 500)
#
# Run: 642, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 122.7, max: 500)
#
# Run: 643, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 122.5, max: 500)
#
# Run: 644, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 123.08, max: 500)
#
# Run: 645, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 122.62, max: 500)
#
# Run: 646, exploration: 0.01, score: 245
# Scores: (min: 10, avg: 122.79, max: 500)
#
# Run: 647, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 120.14, max: 500)
#
# Run: 648, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 118.79, max: 500)
#
# Run: 649, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 120.11, max: 500)
#
# Run: 650, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 120.52, max: 500)
#
# Run: 651, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 121.12, max: 500)
#
# Run: 652, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 121.67, max: 500)
#
# Run: 653, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 122.3, max: 500)
#
# Run: 654, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 123.24, max: 500)
#
# Run: 655, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 124.06, max: 500)
#
# Run: 656, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 124.09, max: 500)
#
# Run: 657, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 124.95, max: 500)
#
# Run: 658, exploration: 0.01, score: 354
# Scores: (min: 10, avg: 128.37, max: 500)
#
# Run: 659, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 128.7, max: 500)
#
# Run: 660, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 129.85, max: 500)
#
# Run: 661, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 131.08, max: 500)
#
# Run: 662, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 131.19, max: 500)
#
# Run: 663, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 131.36, max: 500)
#
# Run: 664, exploration: 0.01, score: 26
# Scores: (min: 11, avg: 131.52, max: 500)
#
# Run: 665, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 131.33, max: 500)
#
# Run: 666, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 130.74, max: 500)
#
# Run: 667, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 131.37, max: 500)
#
# Run: 668, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 127.89, max: 500)
#
# Run: 669, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 126.75, max: 500)
#
# Run: 670, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 125.19, max: 500)
#
# Run: 671, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 125.28, max: 500)
#
# Run: 672, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 124.5, max: 500)
#
# Run: 673, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 124.48, max: 500)
#
# Run: 674, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 124.43, max: 500)
#
# Run: 675, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 123.91, max: 500)
#
# Run: 676, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 123.58, max: 500)
#
# Run: 677, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 119.1, max: 500)
#
# Run: 678, exploration: 0.01, score: 47
# Scores: (min: 11, avg: 118.19, max: 500)
#
# Run: 679, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 116.66, max: 500)
#
# Run: 680, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 115.67, max: 500)
#
# Run: 681, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 110.85, max: 365)
#
# Run: 682, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 110.99, max: 365)
#
# Run: 683, exploration: 0.01, score: 44
# Scores: (min: 11, avg: 111.23, max: 365)
#
# Run: 684, exploration: 0.01, score: 72
# Scores: (min: 11, avg: 110.05, max: 365)
#
# Run: 685, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 110.35, max: 365)
#
# Run: 686, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 111.23, max: 365)
#
# Run: 687, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 111.11, max: 365)
#
# Run: 688, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 112.06, max: 365)
#
# Run: 689, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 110.89, max: 365)
#
# Run: 690, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 111.09, max: 365)
#
# Run: 691, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 110.26, max: 365)
#
# Run: 692, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 110.23, max: 365)

# %%
GAMA = 0.95  # Reset Param
# Experiment 3: Modify Learning Rate
LEARNING_RATE = 0.01  # Increase learning rate for faster updates

# Re-run the cartpole function with updated parameters
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.946354579813443, score: 20
# Scores: (min: 11, avg: 15.5, max: 20)
#
# Run: 3, exploration: 0.7705488893118823, score: 42
# Scores: (min: 11, avg: 24.333333333333332, max: 42)
#
# Run: 4, exploration: 0.7292124703704616, score: 12
# Scores: (min: 11, avg: 21.25, max: 42)
#
# Run: 5, exploration: 0.6935613678313175, score: 11
# Scores: (min: 11, avg: 19.2, max: 42)
#
# Run: 6, exploration: 0.653073201944699, score: 13
# Scores: (min: 11, avg: 18.166666666666668, max: 42)
#
# Run: 7, exploration: 0.6118738784280476, score: 14
# Scores: (min: 11, avg: 17.571428571428573, max: 42)
#
# Run: 8, exploration: 0.567555222460375, score: 16
# Scores: (min: 11, avg: 17.375, max: 42)
#
# Run: 9, exploration: 0.5344229416520513, score: 13
# Scores: (min: 11, avg: 16.88888888888889, max: 42)
#
# Run: 10, exploration: 0.4982051627146237, score: 15
# Scores: (min: 11, avg: 16.7, max: 42)
#
# Run: 11, exploration: 0.47622912292284103, score: 10
# Scores: (min: 10, avg: 16.09090909090909, max: 42)
#
# Run: 12, exploration: 0.446186062443672, score: 14
# Scores: (min: 10, avg: 15.916666666666666, max: 42)
#
# Run: 13, exploration: 0.42013897252428334, score: 13
# Scores: (min: 10, avg: 15.692307692307692, max: 42)
#
# Run: 14, exploration: 0.3995984329713264, score: 11
# Scores: (min: 10, avg: 15.357142857142858, max: 42)
#
# Run: 15, exploration: 0.3669578217261671, score: 18
# Scores: (min: 10, avg: 15.533333333333333, max: 42)
#
# Run: 16, exploration: 0.3507711574848344, score: 10
# Scores: (min: 10, avg: 15.1875, max: 42)
#
# Run: 17, exploration: 0.33362200135903064, score: 11
# Scores: (min: 10, avg: 14.941176470588236, max: 42)
#
# Run: 18, exploration: 0.29729358661854943, score: 24
# Scores: (min: 10, avg: 15.444444444444445, max: 42)
#
# Run: 19, exploration: 0.23255008201124722, score: 50
# Scores: (min: 10, avg: 17.263157894736842, max: 50)
#
# Run: 20, exploration: 0.1912566947289212, score: 40
# Scores: (min: 10, avg: 18.4, max: 50)
#
# Run: 21, exploration: 0.1526354036900377, score: 46
# Scores: (min: 10, avg: 19.714285714285715, max: 50)
#
# Run: 22, exploration: 0.12807462877562611, score: 36
# Scores: (min: 10, avg: 20.454545454545453, max: 50)
#
# Run: 23, exploration: 0.09528507271768329, score: 60
# Scores: (min: 10, avg: 22.17391304347826, max: 60)
#
# Run: 24, exploration: 0.0832238973628649, score: 28
# Scores: (min: 10, avg: 22.416666666666668, max: 60)
#
# Run: 25, exploration: 0.06477420436570952, score: 51
# Scores: (min: 10, avg: 23.56, max: 60)
#
# Run: 26, exploration: 0.058595424120670696, score: 21
# Scores: (min: 10, avg: 23.46153846153846, max: 60)
#
# Run: 27, exploration: 0.0543512971290831, score: 16
# Scores: (min: 10, avg: 23.185185185185187, max: 60)
#
# Run: 28, exploration: 0.0451506389749415, score: 38
# Scores: (min: 10, avg: 23.714285714285715, max: 60)
#
# Run: 29, exploration: 0.0386526615487428, score: 32
# Scores: (min: 10, avg: 24, max: 60)
#
# Run: 30, exploration: 0.03694767635022522, score: 10
# Scores: (min: 10, avg: 23.533333333333335, max: 60)
#
# Run: 31, exploration: 0.035673744367776934, score: 8
# Scores: (min: 8, avg: 23.032258064516128, max: 60)
#
# Run: 32, exploration: 0.034100160462149656, score: 10
# Scores: (min: 8, avg: 22.625, max: 60)
#
# Run: 33, exploration: 0.03275978694079333, score: 9
# Scores: (min: 8, avg: 22.21212121212121, max: 60)
#
# Run: 34, exploration: 0.03147209942303359, score: 9
# Scores: (min: 8, avg: 21.823529411764707, max: 60)
#
# Run: 35, exploration: 0.03038696179137978, score: 8
# Scores: (min: 8, avg: 21.428571428571427, max: 60)
#
# Run: 36, exploration: 0.02904658009432929, score: 10
# Scores: (min: 8, avg: 21.11111111111111, max: 60)
#
# Run: 37, exploration: 0.027765323199097504, score: 10
# Scores: (min: 8, avg: 20.81081081081081, max: 60)
#
# Run: 38, exploration: 0.02654058308574668, score: 10
# Scores: (min: 8, avg: 20.526315789473685, max: 60)
#
# Run: 39, exploration: 0.024866262250633264, score: 14
# Scores: (min: 8, avg: 20.358974358974358, max: 60)
#
# Run: 40, exploration: 0.019353724157029815, score: 51
# Scores: (min: 8, avg: 21.125, max: 60)
#
# Run: 41, exploration: 0.012639398604785928, score: 86
# Scores: (min: 8, avg: 22.70731707317073, max: 86)
#
# Run: 42, exploration: 0.010820365061092144, score: 32
# Scores: (min: 8, avg: 22.928571428571427, max: 86)
#
# Run: 43, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.11627906976744, max: 86)
#
# Run: 44, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 23.454545454545453, max: 86)
#
# Run: 45, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.4, max: 86)
#
# Run: 46, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23.41304347826087, max: 86)
#
# Run: 47, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 23.72340425531915, max: 86)
#
# Run: 48, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.6875, max: 86)
#
# Run: 49, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 23.979591836734695, max: 86)
#
# Run: 50, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 24.26, max: 86)
#
# Run: 51, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.50980392156863, max: 86)
#
# Run: 52, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 25.423076923076923, max: 86)
#
# Run: 53, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 25.641509433962263, max: 86)
#
# Run: 54, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 25.51851851851852, max: 86)
#
# Run: 55, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 26.4, max: 86)
#
# Run: 56, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 26.428571428571427, max: 86)
#
# Run: 57, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 26.45614035087719, max: 86)
#
# Run: 58, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 26.517241379310345, max: 86)
#
# Run: 59, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 26.559322033898304, max: 86)
#
# Run: 60, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 26.666666666666668, max: 86)
#
# Run: 61, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 27.229508196721312, max: 86)
#
# Run: 62, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 27.274193548387096, max: 86)
#
# Run: 63, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 27.158730158730158, max: 86)
#
# Run: 64, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 27.484375, max: 86)
#
# Run: 65, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 28.307692307692307, max: 86)
#
# Run: 66, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 28.12121212121212, max: 86)
#
# Run: 67, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 28.074626865671643, max: 86)
#
# Run: 68, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 28.029411764705884, max: 86)
#
# Run: 69, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 28.36231884057971, max: 86)
#
# Run: 70, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 28.485714285714284, max: 86)
#
# Run: 71, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 28.577464788732396, max: 86)
#
# Run: 72, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 28.958333333333332, max: 86)
#
# Run: 73, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 28.73972602739726, max: 86)
#
# Run: 74, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 29.10810810810811, max: 86)
#
# Run: 75, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 28.92, max: 86)
#
# Run: 76, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 28.92105263157895, max: 86)
#
# Run: 77, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 28.727272727272727, max: 86)
#
# Run: 78, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.487179487179485, max: 86)
#
# Run: 79, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.265822784810126, max: 86)
#
# Run: 80, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.0375, max: 86)
#
# Run: 81, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.814814814814813, max: 86)
#
# Run: 82, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.597560975609756, max: 86)
#
# Run: 83, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 27.44578313253012, max: 86)
#
# Run: 84, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 28.44047619047619, max: 111)
#
# Run: 85, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 28.658823529411766, max: 111)
#
# Run: 86, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 28.46511627906977, max: 111)
#
# Run: 87, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 29.195402298850574, max: 111)
#
# Run: 88, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 29.03409090909091, max: 111)
# Run: 89, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 29.50561797752809, max: 111)
#
# Run: 90, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 30.044444444444444, max: 111)
#
# Run: 91, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 29.9010989010989, max: 111)
#
# Run: 92, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 29.76086956521739, max: 111)
#
# Run: 93, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 29.526881720430108, max: 111)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.319148936170212, max: 111)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.11578947368421, max: 111)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.90625, max: 111)
#
# Run: 97, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.690721649484537, max: 111)
#
# Run: 98, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.489795918367346, max: 111)
#
# Run: 99, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.303030303030305, max: 111)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.12, max: 111)
#
# Run: 101, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.1, max: 111)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28, max: 111)
#
# Run: 103, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.69, max: 111)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.67, max: 111)
#
# Run: 105, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.67, max: 111)
#
# Run: 106, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.62, max: 111)
#
# Run: 107, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.57, max: 111)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.5, max: 111)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.47, max: 111)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.42, max: 111)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.42, max: 111)
#
# Run: 112, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.39, max: 111)
#
# Run: 113, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.4, max: 111)
#
# Run: 114, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 27.51, max: 111)
#
# Run: 115, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.49, max: 111)
#
# Run: 116, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.55, max: 111)
#
# Run: 117, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 27.85, max: 111)
#
# Run: 118, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 27.93, max: 111)
#
# Run: 119, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 27.6, max: 111)
#
# Run: 120, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 27.56, max: 111)
#
# Run: 121, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 27.75, max: 111)
#
# Run: 122, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 27.77, max: 111)
#
# Run: 123, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 27.63, max: 111)
#
# Run: 124, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 27.53, max: 111)
#
# Run: 125, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 27.3, max: 111)
#
# Run: 126, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 27.3, max: 111)
#
# Run: 127, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 27.42, max: 111)
#
# Run: 128, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 27.51, max: 111)
#
# Run: 129, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 27.49, max: 111)
#
# Run: 130, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.55, max: 111)
#
# Run: 131, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 28.08, max: 111)
#
# Run: 132, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 28.35, max: 111)
#
# Run: 133, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 28.45, max: 111)
#
# Run: 134, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 28.55, max: 111)
#
# Run: 135, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 28.66, max: 111)
#
# Run: 136, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 28.73, max: 111)
#
# Run: 137, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 28.87, max: 111)
#
# Run: 138, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 28.98, max: 111)
#
# Run: 139, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 29.14, max: 111)
#
# Run: 140, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 28.8, max: 111)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.03, max: 111)
#
# Run: 142, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.85, max: 111)
#
# Run: 143, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 27.97, max: 111)
#
# Run: 144, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 27.94, max: 111)
#
# Run: 145, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 28.28, max: 111)
#
# Run: 146, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 28.48, max: 111)
#
# Run: 147, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 28.9, max: 111)
#
# Run: 148, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 28.9, max: 111)
#
# Run: 149, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 28.78, max: 111)
#
# Run: 150, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 29.33, max: 111)
#
# Run: 151, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 29.24, max: 111)
#
# Run: 152, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 28.72, max: 111)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.45, max: 111)
#
# Run: 154, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.34, max: 111)
#
# Run: 155, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.71, max: 111)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.52, max: 111)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.33, max: 111)
#
# Run: 158, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.11, max: 111)
#
# Run: 159, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.92, max: 111)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.68, max: 111)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.16, max: 111)
#
# Run: 162, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.95, max: 111)
#
# Run: 163, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.83, max: 111)
#
# Run: 164, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.43, max: 111)
#
# Run: 165, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.71, max: 111)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.65, max: 111)
#
# Run: 167, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.49, max: 111)
#
# Run: 168, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.34, max: 111)
#
# Run: 169, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.93, max: 111)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.65, max: 111)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.4, max: 111)
#
# Run: 172, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.94, max: 111)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.9, max: 111)
#
# Run: 174, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.42, max: 111)
#
# Run: 175, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.36, max: 111)
#
# Run: 176, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.16, max: 111)
#
# Run: 177, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 22.19, max: 111)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.18, max: 111)
#
# Run: 179, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.17, max: 111)
#
# Run: 180, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.18, max: 111)
#
# Run: 181, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.27, max: 111)
#
# Run: 182, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.3, max: 111)
#
# Run: 183, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 22.7, max: 111)
#
# Run: 184, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.71, max: 93)
#
# Run: 185, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.36, max: 93)
#
# Run: 186, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 21.77, max: 93)
#
# Run: 187, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 21.24, max: 93)
#
# Run: 188, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 21.78, max: 93)
#
# Run: 189, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 21.81, max: 93)
#
# Run: 190, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 21.66, max: 93)
#
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.59, max: 93)
# Run: 192, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 21.81, max: 93)
#
# Run: 193, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 22.58, max: 93)
#
# Run: 194, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.69, max: 93)
#
# Run: 195, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 23.73, max: 114)
#
# Run: 196, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 24.75, max: 114)
#
# Run: 197, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 25.06, max: 114)
#
# Run: 198, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 25.3, max: 114)
#
# Run: 199, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.34, max: 114)
#
# Run: 200, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 25.85, max: 114)
#
# Run: 201, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 26.96, max: 120)
#
# Run: 202, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 27.05, max: 120)
#
# Run: 203, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 27.54, max: 120)
#
# Run: 204, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 28.76, max: 132)
#
# Run: 205, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 29.48, max: 132)
#
# Run: 206, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 30.32, max: 132)
#
# Run: 207, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 30.7, max: 132)
#
# Run: 208, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 31.57, max: 132)
#
# Run: 209, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 31.92, max: 132)
#
# Run: 210, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.91, max: 132)
#
# Run: 211, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.92, max: 132)
#
# Run: 212, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.92, max: 132)
#
# Run: 213, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 31.99, max: 132)
#
# Run: 214, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 31.89, max: 132)
#
# Run: 215, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 32.3, max: 132)
#
# Run: 216, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 34.37, max: 223)
#
# Run: 217, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.06, max: 223)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.84, max: 223)
#
# Run: 219, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.76, max: 223)
#
# Run: 220, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.5, max: 223)
#
# Run: 221, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.94, max: 223)
#
# Run: 222, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 32.64, max: 223)
#
# Run: 223, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.27, max: 223)
#
# Run: 224, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.19, max: 223)
#
# Run: 225, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.01, max: 223)
#
# Run: 226, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.9, max: 223)
#
# Run: 227, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 31.7, max: 223)
#
# Run: 228, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.33, max: 223)
#
# Run: 229, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 31.11, max: 223)
#
# Run: 230, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.04, max: 223)
#
# Run: 231, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.52, max: 223)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.25, max: 223)
#
# Run: 233, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.15, max: 223)
#
# Run: 234, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.04, max: 223)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.95, max: 223)
#
# Run: 236, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 29.98, max: 223)
#
# Run: 237, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.84, max: 223)
#
# Run: 238, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 29.95, max: 223)
#
# Run: 239, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 30.75, max: 223)
#
# Run: 240, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 31.57, max: 223)
#
# Run: 241, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 32.02, max: 223)
#
# Run: 242, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 32.39, max: 223)
#
# Run: 243, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 32.09, max: 223)
#
# Run: 244, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 31.92, max: 223)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.47, max: 223)
#
# Run: 246, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.13, max: 223)
#
# Run: 247, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.42, max: 223)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.29, max: 223)
#
# Run: 249, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.13, max: 223)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.31, max: 223)
#
# Run: 251, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.12, max: 223)
#
# Run: 252, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 29.49, max: 223)
#
# Run: 253, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.49, max: 223)
#
# Run: 254, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 29.99, max: 223)
#
# Run: 255, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 30.58, max: 223)
#
# Run: 256, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 31.03, max: 223)
#
# Run: 257, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 31.58, max: 223)
#
# Run: 258, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.61, max: 223)
#
# Run: 259, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 32.07, max: 223)
#
# Run: 260, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 32.4, max: 223)
#
# Run: 261, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 32.43, max: 223)
#
# Run: 262, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 32.53, max: 223)
#
# Run: 263, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 32.6, max: 223)
#
# Run: 264, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 32.93, max: 223)
#
# Run: 265, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 33.3, max: 223)
#
# Run: 266, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 34.08, max: 223)
#
# Run: 267, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 34.13, max: 223)
#
# Run: 268, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 34.41, max: 223)
#
# Run: 269, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 35.27, max: 223)
#
# Run: 270, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 35.35, max: 223)
#
# Run: 271, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 35.85, max: 223)
#
# Run: 272, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 36.02, max: 223)
#
# Run: 273, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 36.48, max: 223)
#
# Run: 274, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 37.24, max: 223)
#
# Run: 275, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 37.39, max: 223)
#
# Run: 276, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 38.01, max: 223)
#
# Run: 277, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 38.75, max: 223)
#
# Run: 278, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 39.07, max: 223)
#
# Run: 279, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 39.41, max: 223)
#
# Run: 280, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 40.45, max: 223)
#
# Run: 281, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.37, max: 223)
#
# Run: 282, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.35, max: 223)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.89, max: 223)
#
# Run: 284, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.07, max: 223)
#
# Run: 285, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 41.98, max: 223)
#
# Run: 286, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 42.01, max: 223)
#
# Run: 287, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 41.85, max: 223)
#
# Run: 288, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 41.36, max: 223)
#
# Run: 289, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.72, max: 223)
#
# Run: 290, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 40.59, max: 223)
#
# Run: 291, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 40.74, max: 223)
#
# Run: 292, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.65, max: 223)
#
# Run: 293, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 40.52, max: 223)
#
# Run: 294, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 40.62, max: 223)
#
# Run: 295, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 40.5, max: 223)
# Run: 296, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 39.76, max: 223)
#
# Run: 297, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 39.5, max: 223)
#
# Run: 298, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 39.38, max: 223)
#
# Run: 299, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 39.43, max: 223)
#
# Run: 300, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 40.27, max: 223)
#
# Run: 301, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 39.25, max: 223)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.16, max: 223)
#
# Run: 303, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 38.68, max: 223)
#
# Run: 304, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 37.6, max: 223)
#
# Run: 305, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 37.68, max: 223)
#
# Run: 306, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 37.7, max: 223)
#
# Run: 307, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 37.6, max: 223)
#
# Run: 308, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 37.77, max: 223)
#
# Run: 309, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 38.26, max: 223)
#
# Run: 310, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 40.04, max: 223)
#
# Run: 311, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 41.71, max: 223)
#
# Run: 312, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.7, max: 223)
#
# Run: 313, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.59, max: 223)
#
# Run: 314, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.57, max: 223)
#
# Run: 315, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.09, max: 223)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.95, max: 203)
#
# Run: 317, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.95, max: 203)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.94, max: 203)
#
# Run: 319, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.96, max: 203)
#
# Run: 320, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.96, max: 203)
#
# Run: 321, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.97, max: 203)
#
# Run: 322, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.99, max: 203)
#
# Run: 323, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39, max: 203)
#
# Run: 324, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.98, max: 203)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.97, max: 203)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.96, max: 203)
#
# Run: 327, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.98, max: 203)
#
# Run: 328, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.98, max: 203)
#
# Run: 329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39, max: 203)
#
# Run: 330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39, max: 203)
#
# Run: 331, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.01, max: 203)
#
# Run: 332, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.01, max: 203)
#
# Run: 333, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.01, max: 203)
#
# Run: 334, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 39.01, max: 203)
#
# Run: 335, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39, max: 203)
#
# Run: 336, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.88, max: 203)
#
# Run: 337, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.86, max: 203)
#
# Run: 338, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.64, max: 203)
#
# Run: 339, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.63, max: 203)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.73, max: 203)
#
# Run: 341, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.28, max: 203)
#
# Run: 342, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.86, max: 203)
#
# Run: 343, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.83, max: 203)
#
# Run: 344, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.74, max: 203)
#
# Run: 345, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.74, max: 203)
#
# Run: 346, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.74, max: 203)
#
# Run: 347, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 37.48, max: 203)
#
# Run: 348, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 38.37, max: 203)
#
# Run: 349, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 38.94, max: 203)
#
# Run: 350, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 39.22, max: 203)
#
# Run: 351, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 39.34, max: 203)
#
# Run: 352, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 39.17, max: 203)
#
# Run: 353, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 39.95, max: 203)
#
# Run: 354, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 40.75, max: 203)
#
# Run: 355, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 40.39, max: 203)
#
# Run: 356, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 42.49, max: 264)
#
# Run: 357, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 43.13, max: 264)
#
# Run: 358, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 44.75, max: 264)
#
# Run: 359, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 44.67, max: 264)
#
# Run: 360, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 44.39, max: 264)
#
# Run: 361, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 44.9, max: 264)
#
# Run: 362, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.8, max: 264)
#
# Run: 363, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.75, max: 264)
#
# Run: 364, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.43, max: 264)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.07, max: 264)
#
# Run: 366, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.28, max: 264)
#
# Run: 367, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.24, max: 264)
#
# Run: 368, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.96, max: 264)
#
# Run: 369, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.09, max: 264)
#
# Run: 370, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.01, max: 264)
#
# Run: 371, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.51, max: 264)
#
# Run: 372, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.34, max: 264)
#
# Run: 373, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.88, max: 264)
#
# Run: 374, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.14, max: 264)
#
# Run: 375, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.99, max: 264)
#
# Run: 376, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.38, max: 264)
#
# Run: 377, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.56, max: 264)
#
# Run: 378, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.26, max: 264)
#
# Run: 379, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.91, max: 264)
#
# Run: 380, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.84, max: 264)
#
# Run: 381, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.82, max: 264)
#
# Run: 382, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.8, max: 264)
#
# Run: 383, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.8, max: 264)
#
# Run: 384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.59, max: 264)
#
# Run: 385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.65, max: 264)
#
# Run: 386, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.19, max: 264)
#
# Run: 387, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.04, max: 264)
#
# Run: 388, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 33.92, max: 264)
#
# Run: 389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.91, max: 264)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.5, max: 264)
#
# Run: 391, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.34, max: 264)
#
# Run: 392, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.13, max: 264)
#
# Run: 393, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.5, max: 264)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.28, max: 264)
#
# Run: 395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.36, max: 264)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.09, max: 264)
#
# Run: 397, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.05, max: 264)
#
# Run: 398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.94, max: 264)
#
# Run: 399, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.84, max: 264)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.48, max: 264)
# Run: 401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.39, max: 264)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.39, max: 264)
#
# Run: 403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.37, max: 264)
#
# Run: 404, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.24, max: 264)
#
# Run: 405, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.41, max: 264)
#
# Run: 406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.57, max: 264)
#
# Run: 407, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.31, max: 264)
#
# Run: 408, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.27, max: 264)
#
# Run: 409, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.43, max: 264)
#
# Run: 410, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.65, max: 264)
#
# Run: 411, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.96, max: 264)
#
# Run: 412, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.96, max: 264)
#
# Run: 413, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.95, max: 264)
#
# Run: 414, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 415, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 416, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 418, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 419, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 420, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 421, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 422, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.92, max: 264)
#
# Run: 424, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.92, max: 264)
#
# Run: 425, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 426, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 427, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.92, max: 264)
#
# Run: 428, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.9, max: 264)
#
# Run: 429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.9, max: 264)
#
# Run: 430, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 431, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.91, max: 264)
#
# Run: 432, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.89, max: 264)
#
# Run: 433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.89, max: 264)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.91, max: 264)
#
# Run: 435, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.91, max: 264)
#
# Run: 436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 264)
#
# Run: 437, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 438, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.94, max: 264)
#
# Run: 439, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.95, max: 264)
#
# Run: 440, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.95, max: 264)
#
# Run: 441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.96, max: 264)
#
# Run: 442, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.98, max: 264)
#
# Run: 443, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.98, max: 264)
#
# Run: 444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.98, max: 264)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.97, max: 264)
#
# Run: 446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.96, max: 264)
#
# Run: 447, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.22, max: 264)
#
# Run: 448, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 19.63, max: 264)
#
# Run: 449, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.34, max: 264)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.04, max: 264)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.92, max: 264)
#
# Run: 452, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.61, max: 264)
#
# Run: 453, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.82, max: 264)
#
# Run: 454, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.53, max: 264)
#
# Run: 455, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.28, max: 264)
#
# Run: 456, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.74, max: 173)
#
# Run: 457, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 173)
#
# Run: 458, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.93, max: 63)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.55, max: 63)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.51, max: 63)
#
# Run: 461, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 462, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 463, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.96, max: 39)
#
# Run: 464, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 465, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.96, max: 39)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 467, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 468, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 470, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 471, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 473, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 474, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 475, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 476, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 477, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 478, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 479, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 481, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 482, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 483, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.96, max: 39)
#
# Run: 484, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 39)
#
# Run: 485, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 39)
#
# Run: 487, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.99, max: 39)
#
# Run: 488, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.01, max: 39)
#
# Run: 489, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.01, max: 39)
#
# Run: 490, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.01, max: 39)
#
# Run: 491, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.02, max: 39)
#
# Run: 492, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 39)
#
# Run: 493, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.04, max: 39)
#
# Run: 494, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.03, max: 39)
#
# Run: 495, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 39)
#
# Run: 496, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.05, max: 39)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.06, max: 39)
#
# Run: 498, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.07, max: 39)
#
# Run: 499, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.08, max: 39)
#
# Run: 500, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.09, max: 39)
#
# Run: 501, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 502, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.31, max: 39)
#
# Run: 503, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.36, max: 39)
#
# Run: 504, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.35, max: 39)
#
# Run: 505, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.36, max: 39)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 39)
# Run: 507, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 508, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.34, max: 39)
#
# Run: 509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 510, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.35, max: 39)
#
# Run: 511, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 39)
#
# Run: 512, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.34, max: 39)
#
# Run: 513, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 514, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 515, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 516, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 517, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 518, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 519, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.36, max: 39)
#
# Run: 520, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.35, max: 39)
#
# Run: 521, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.34, max: 39)
#
# Run: 522, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 523, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 524, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.34, max: 39)
#
# Run: 525, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 526, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 527, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.33, max: 39)
#
# Run: 528, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.36, max: 39)
#
# Run: 529, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.4, max: 39)
#
# Run: 530, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.37, max: 39)
#
# Run: 531, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.39, max: 39)
#
# Run: 532, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.4, max: 39)
#
# Run: 533, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.52, max: 39)
#
# Run: 534, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 39)
#
# Run: 535, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.53, max: 39)
#
# Run: 536, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.52, max: 39)
#
# Run: 537, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.61, max: 39)
#
# Run: 538, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 10.74, max: 39)
#
# Run: 539, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.75, max: 39)
#
# Run: 540, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.76, max: 39)
#
# Run: 541, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 11.11, max: 45)
#
# Run: 542, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 11.28, max: 45)
#
# Run: 543, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.33, max: 45)
#
# Run: 544, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.39, max: 45)
#
# Run: 545, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 45)
#
# Run: 546, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.4, max: 45)
#
# Run: 547, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.44, max: 45)
#
# Run: 548, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.21, max: 45)
#
# Run: 549, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.97, max: 45)
#
# Run: 550, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.02, max: 45)
#
# Run: 551, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.02, max: 45)
#
# Run: 552, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.1, max: 45)
#
# Run: 553, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 45)
#
# Run: 554, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.15, max: 45)
#
# Run: 555, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 11.43, max: 45)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.43, max: 45)
#
# Run: 557, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.42, max: 45)
#
# Run: 558, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.42, max: 45)
#
# Run: 559, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.44, max: 45)
#
# Run: 560, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.57, max: 45)
#
# Run: 561, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.57, max: 45)
#
# Run: 562, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.58, max: 45)
#
# Run: 563, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.67, max: 45)
#
# Run: 564, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 11.86, max: 45)
#
# Run: 565, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.93, max: 45)
#
# Run: 566, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.04, max: 45)
#
# Run: 567, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 12.34, max: 45)
#
# Run: 568, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.35, max: 45)
#
# Run: 569, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.45, max: 45)
#
# Run: 570, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.58, max: 45)
#
# Run: 571, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.62, max: 45)
#
# Run: 572, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.75, max: 45)
#
# Run: 573, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.77, max: 45)
#
# Run: 574, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.82, max: 45)
#
# Run: 575, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.88, max: 45)
#
# Run: 576, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.89, max: 45)
#
# Run: 577, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.94, max: 45)
#
# Run: 578, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 13.33, max: 49)
#
# Run: 579, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.35, max: 49)
#
# Run: 580, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.51, max: 49)
#
# Run: 581, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.52, max: 49)
#
# Run: 582, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.67, max: 49)
#
# Run: 583, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.69, max: 49)
#
# Run: 584, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.83, max: 49)
#
# Run: 585, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14, max: 49)
#
# Run: 586, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.06, max: 49)
#
# Run: 587, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.09, max: 49)
#
# Run: 588, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.1, max: 49)
#
# Run: 589, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.2, max: 49)
#
# Run: 590, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.25, max: 49)
#
# Run: 591, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.26, max: 49)
#
# Run: 592, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.29, max: 49)
#
# Run: 593, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.34, max: 49)
#
# Run: 594, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.45, max: 49)
#
# ...
# Scores: (min: 9, avg: 20.19, max: 55)
#
# Run: 2033, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 20.04, max: 55)
#
# Run: 2034, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 20, max: 55)
#
# Run: 2035, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.75, max: 55)
#
# Run: 2036, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.68, max: 55)
#
# Run: 2037, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.73, max: 55)
#
# Run: 2038, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.68, max: 55)
#
# Run: 2039, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.62, max: 55)
#
# Run: 2040, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.63, max: 55)
#
# Run: 2041, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.63, max: 55)
#
# Run: 2042, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.61, max: 55)
#
# Run: 2043, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.51, max: 55)
#
# Run: 2044, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.41, max: 55)
#
# Run: 2045, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.14, max: 55)
#
# Run: 2046, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.07, max: 55)
#
# Run: 2047, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.79, max: 52)
#
# Run: 2048, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.73, max: 52)
#
# Run: 2049, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.74, max: 52)
#
# Run: 2050, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.74, max: 52)
#
# Run: 2051, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.59, max: 52)
#
# Run: 2052, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 18.91, max: 52)
#
# Run: 2053, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.92, max: 52)
#
# Run: 2054, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.86, max: 52)
#
# Run: 2055, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 19.28, max: 52)
#
# Run: 2056, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.39, max: 52)
#
# Run: 2057, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.39, max: 52)
#
# Run: 2058, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.42, max: 52)
#
# Run: 2059, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.4, max: 52)
#
# Run: 2060, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.28, max: 52)
#
# Run: 2061, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.36, max: 52)
#
# Run: 2062, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.48, max: 52)
#
# Run: 2063, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.5, max: 52)
#
# Run: 2064, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.4, max: 52)
#
# Run: 2065, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.23, max: 52)
#
# Run: 2066, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.31, max: 52)
#
# Run: 2067, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.28, max: 52)
#
# Run: 2068, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.29, max: 52)
#
# Run: 2069, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19.31, max: 52)
#
# Run: 2070, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 19.88, max: 83)
#
# Run: 2071, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.7, max: 83)
#
# Run: 2072, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.74, max: 83)
#
# Run: 2073, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.71, max: 83)
#
# Run: 2074, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.82, max: 83)
#
# Run: 2075, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 20.01, max: 83)
#
# Run: 2076, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.7, max: 83)
#
# Run: 2077, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.6, max: 83)
#
# Run: 2078, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.43, max: 83)
#
# Run: 2079, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.25, max: 83)
#
# Run: 2080, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.3, max: 83)
#
# Run: 2081, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.43, max: 83)
#
# Run: 2082, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.58, max: 83)
#
# Run: 2083, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 19.69, max: 83)
# Run: 2084, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 19.83, max: 83)
#
# Run: 2085, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 20.03, max: 83)
#
# Run: 2086, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 20.32, max: 83)
#
# Run: 2087, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 21.68, max: 162)
#
# Run: 2088, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 22.76, max: 162)
#
# Run: 2089, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 23.84, max: 162)
#
# Run: 2090, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 25.56, max: 182)
#
# Run: 2091, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 27.01, max: 184)
#
# Run: 2092, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 28.39, max: 184)
#
# Run: 2093, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 29.5, max: 184)
#
# Run: 2094, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 31.77, max: 245)
#
# Run: 2095, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 33.07, max: 245)
#
# Run: 2096, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 34.46, max: 245)
#
# Run: 2097, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 35.53, max: 245)
#
# Run: 2098, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 36.95, max: 245)
#
# Run: 2099, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 38.24, max: 245)
#
# Run: 2100, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 39.25, max: 245)
#
# Run: 2101, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 40.19, max: 245)
#
# Run: 2102, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 41.68, max: 245)
#
# Run: 2103, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 42.76, max: 245)
#
# Run: 2104, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 44.49, max: 245)
#
# Run: 2105, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 46.05, max: 245)
#
# Run: 2106, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 47.67, max: 245)
#
# Run: 2107, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 49.08, max: 245)
#
# Run: 2108, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 50.95, max: 245)
#
# Run: 2109, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 52.39, max: 245)
#
# Run: 2110, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 53.67, max: 245)
#
# Run: 2111, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 55.83, max: 245)
#
# Run: 2112, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 57.47, max: 245)
#
# Run: 2113, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 59.19, max: 245)
#
# Run: 2114, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 60.34, max: 245)
#
# Run: 2115, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 61.33, max: 245)
#
# Run: 2116, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 62.84, max: 245)
#
# Run: 2117, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 64.71, max: 245)
#
# Run: 2118, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 65.64, max: 245)
#
# Run: 2119, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 66.95, max: 245)
#
# Run: 2120, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 68.3, max: 245)
#
# Run: 2121, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 69.71, max: 245)
#
# Run: 2122, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 70.97, max: 245)
#
# Run: 2123, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 72.6, max: 245)
#
# Run: 2124, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 73.95, max: 245)
#
# Run: 2125, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 75.25, max: 245)
#
# Run: 2126, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 76.59, max: 245)
#
# Run: 2127, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 77.63, max: 245)
#
# Run: 2128, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 78.85, max: 245)
#
# Run: 2129, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 79.99, max: 245)
#
# Run: 2130, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 81.2, max: 245)
#
# Run: 2131, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 81.95, max: 245)
#
# Run: 2132, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 83.3, max: 245)
#
# Run: 2133, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 84.84, max: 245)
#
# Run: 2134, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 85.9, max: 245)
#
# Run: 2135, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 86.54, max: 245)
#
# Run: 2136, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 86.58, max: 245)
#
# Run: 2137, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 86.49, max: 245)
#
# Run: 2138, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 86.52, max: 245)
#
# Run: 2139, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 87.09, max: 245)
#
# Run: 2140, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 88.82, max: 245)
#
# Run: 2141, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 90.12, max: 245)
#
# Run: 2142, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 91.75, max: 245)
#
# Run: 2143, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 93.68, max: 245)
#
# Run: 2144, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 95.21, max: 245)
#
# Run: 2145, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 96.82, max: 245)
#
# Run: 2146, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 98.04, max: 245)
#
# Run: 2147, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 99.3, max: 245)
#
# Run: 2148, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 100.99, max: 245)
#
# Run: 2149, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 102.9, max: 245)
#
# Run: 2150, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 104.21, max: 245)
#
# Run: 2151, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 105.7, max: 245)
#
# Run: 2152, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 106.63, max: 245)
#
# Run: 2153, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 108.03, max: 245)
#
# Run: 2154, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 109.89, max: 245)
#
# Run: 2155, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 111.2, max: 245)
#
# Run: 2156, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 113.6, max: 260)
#
# Run: 2157, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 114.93, max: 260)
#
# Run: 2158, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 116.31, max: 260)
#
# Run: 2159, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 118.53, max: 260)
#
# Run: 2160, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 119.98, max: 260)
#
# Run: 2161, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 121.13, max: 260)
#
# Run: 2162, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 123.22, max: 260)
#
# Run: 2163, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 125.16, max: 260)
#
# Run: 2164, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 126.2, max: 260)
#
# Run: 2165, exploration: 0.01, score: 266
# Scores: (min: 9, avg: 128.76, max: 266)
#
# Run: 2166, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 129.6, max: 266)
#
# Run: 2167, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 130.85, max: 266)
#
# Run: 2168, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 131.43, max: 266)
#
# Run: 2169, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 132.4, max: 266)
#
# Run: 2170, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 132.91, max: 266)
#
# Run: 2171, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 134.71, max: 266)
#
# Run: 2172, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 136.16, max: 266)
#
# Run: 2173, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 137.7, max: 266)
#
# Run: 2174, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 140.02, max: 266)
#
# Run: 2175, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 140.97, max: 266)
#
# Run: 2176, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 143.12, max: 266)
#
# Run: 2177, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 144.18, max: 266)
#
# Run: 2178, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 145.22, max: 266)
#
# Run: 2179, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 147.42, max: 266)
#
# Run: 2180, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 149.5, max: 266)
#
# Run: 2181, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 150.45, max: 266)
#
# Run: 2182, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 151.8, max: 266)
#
# Run: 2183, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 153.31, max: 266)
#
# Run: 2184, exploration: 0.01, score: 427
# Scores: (min: 10, avg: 157.04, max: 427)
# Run: 2185, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 159.07, max: 427)
#
# Run: 2186, exploration: 0.01, score: 256
# Scores: (min: 10, avg: 161.25, max: 427)
#
# Run: 2187, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 161.62, max: 427)
#
# Run: 2188, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 162.11, max: 427)
#
# Run: 2189, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 162.17, max: 427)
#
# Run: 2190, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 163.22, max: 427)
#
# Run: 2191, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 163.11, max: 427)
#
# Run: 2192, exploration: 0.01, score: 277
# Scores: (min: 10, avg: 164.21, max: 427)
#
# Run: 2193, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 164.2, max: 427)
#
# Run: 2194, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 163.82, max: 427)
#
# Run: 2195, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 164.54, max: 427)
#
# Run: 2196, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 164.95, max: 427)
#
# Run: 2197, exploration: 0.01, score: 269
# Scores: (min: 10, avg: 166.28, max: 427)
#
# Run: 2198, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 166.79, max: 427)
#
# Run: 2199, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 167.36, max: 427)
#
# Run: 2200, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 167.58, max: 427)
#
# Run: 2201, exploration: 0.01, score: 249
# Scores: (min: 10, avg: 168.88, max: 427)
#
# Run: 2202, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 169.06, max: 427)
#
# Run: 2203, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 170.21, max: 427)
#
# Run: 2204, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 170, max: 427)
#
# Run: 2205, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 169.98, max: 427)
#
# Run: 2206, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 170.49, max: 427)
#
# Run: 2207, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 170.78, max: 427)
#
# Run: 2208, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 171.09, max: 427)
#
# Run: 2209, exploration: 0.01, score: 428
# Scores: (min: 10, avg: 173.81, max: 428)
#
# Run: 2210, exploration: 0.01, score: 317
# Scores: (min: 10, avg: 175.6, max: 428)
#
# Run: 2211, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 175.17, max: 428)
#
# Run: 2212, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 175.7, max: 428)
#
# Run: 2213, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 175.66, max: 428)
#
# Run: 2214, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 175.76, max: 428)
#
# Run: 2215, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 176.27, max: 428)
#
# Run: 2216, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 176.37, max: 428)
#
# Run: 2217, exploration: 0.01, score: 299
# Scores: (min: 10, avg: 177.34, max: 428)
#
# Run: 2218, exploration: 0.01, score: 237
# Scores: (min: 10, avg: 178.67, max: 428)
#
# Run: 2219, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 178.64, max: 428)
#
# Run: 2220, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 178.98, max: 428)
#
# Run: 2221, exploration: 0.01, score: 282
# Scores: (min: 10, avg: 180.25, max: 428)
#
# Run: 2222, exploration: 0.01, score: 429
# Scores: (min: 10, avg: 183.19, max: 429)
#
# Run: 2223, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 183.45, max: 429)
#
# Run: 2224, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 183.8, max: 429)
#
# Run: 2225, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 183.88, max: 429)
#
# Run: 2226, exploration: 0.01, score: 267
# Scores: (min: 10, avg: 184.88, max: 429)
#
# Run: 2227, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 188.61, max: 500)
#
# Run: 2228, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 188.71, max: 500)
#
# Run: 2229, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 189.08, max: 500)

# %%
LEARNING_RATE = 0.001  # Reset Param

# Modify multiple parameters
GAMMA = 0.98  # Slightly higher discount factor
LEARNING_RATE = 0.005  # Moderately increased learning rate
EXPLORATION_DECAY = 0.9  # Longer exploration period

# Run the experiment with the combined modifications
cartpole()
# Out:
# Run: 1, exploration: 0.81, score: 22
# Scores: (min: 22, avg: 22, max: 22)
#
# Run: 2, exploration: 0.13508517176729928, score: 18
# Scores: (min: 18, avg: 20, max: 22)
#
# Run: 3, exploration: 0.0523347633027361, score: 10
# Scores: (min: 10, avg: 16.666666666666668, max: 22)
#
# Run: 4, exploration: 0.020275559590445278, score: 10
# Scores: (min: 10, avg: 15, max: 22)
#
# Run: 5, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13.8, max: 22)
#
# Run: 6, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 13.166666666666666, max: 22)
#
# Run: 7, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.571428571428571, max: 22)
#
# Run: 8, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.25, max: 22)
#
# Run: 9, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12, max: 22)
#
# Run: 10, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.8, max: 22)
#
# Run: 11, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.636363636363637, max: 22)
#
# Run: 12, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 11.416666666666666, max: 22)
#
# Run: 13, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.307692307692308, max: 22)
#
# Run: 14, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.071428571428571, max: 22)
#
# Run: 15, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.866666666666667, max: 22)
#
# Run: 16, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.75, max: 22)
#
# Run: 17, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.705882352941176, max: 22)
#
# Run: 18, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.666666666666666, max: 22)
#
# Run: 19, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.578947368421053, max: 22)
#
# Run: 20, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.5, max: 22)
#
# Run: 21, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.428571428571429, max: 22)
#
# Run: 22, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.363636363636363, max: 22)
#
# Run: 23, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.26086956521739, max: 22)
#
# Run: 24, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 22)
#
# Run: 25, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.24, max: 22)
#
# Run: 26, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.192307692307692, max: 22)
#
# Run: 27, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.25925925925926, max: 22)
#
# Run: 28, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 22)
#
# Run: 29, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.206896551724139, max: 22)
#
# Run: 30, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.233333333333333, max: 22)
#
# Run: 31, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.193548387096774, max: 22)
#
# Run: 32, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.15625, max: 22)
#
# Run: 33, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.090909090909092, max: 22)
#
# Run: 34, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 10.470588235294118, max: 23)
#
# Run: 35, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.457142857142857, max: 23)
#
# Run: 36, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.416666666666666, max: 23)
#
# Run: 37, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.45945945945946, max: 23)
#
# Run: 38, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.421052631578947, max: 23)
#
# Run: 39, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.41025641025641, max: 23)
#
# Run: 40, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.4, max: 23)
#
# Run: 41, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.390243902439025, max: 23)
#
# Run: 42, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.333333333333334, max: 23)
#
# Run: 43, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.325581395348838, max: 23)
#
# Run: 44, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.318181818181818, max: 23)
#
# Run: 45, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28888888888889, max: 23)
#
# Run: 46, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.369565217391305, max: 23)
#
# Run: 47, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.425531914893616, max: 23)
#
# Run: 48, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.479166666666666, max: 23)
#
# Run: 49, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.448979591836734, max: 23)
#
# Run: 50, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.48, max: 23)
#
# Run: 51, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.450980392156863, max: 23)
#
# Run: 52, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.442307692307692, max: 23)
#
# Run: 53, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.433962264150944, max: 23)
#
# Run: 54, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.425925925925926, max: 23)
#
# Run: 55, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.4, max: 23)
#
# Run: 56, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 11.053571428571429, max: 47)
#
# Run: 57, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.12280701754386, max: 47)
#
# Run: 58, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 11.517241379310345, max: 47)
#
# Run: 59, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.76271186440678, max: 47)
#
# Run: 60, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.883333333333333, max: 47)
#
# Run: 61, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.081967213114755, max: 47)
#
# Run: 62, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.241935483870968, max: 47)
#
# Run: 63, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.476190476190476, max: 47)
#
# Run: 64, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.4375, max: 47)
#
# Run: 65, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.415384615384616, max: 47)
#
# Run: 66, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.590909090909092, max: 47)
#
# Run: 67, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.791044776119403, max: 47)
#
# Run: 68, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.014705882352942, max: 47)
#
# Run: 69, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.18840579710145, max: 47)
#
# Run: 70, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.3, max: 47)
#
# Run: 71, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.28169014084507, max: 47)
#
# Run: 72, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.430555555555555, max: 47)
#
# Run: 73, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.575342465753424, max: 47)
#
# Run: 74, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.662162162162161, max: 47)
#
# Run: 75, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 13.88, max: 47)
#
# Run: 76, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 14.302631578947368, max: 47)
#
# Run: 77, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 14.805194805194805, max: 53)
#
# Run: 78, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.871794871794872, max: 53)
#
# Run: 79, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 15.177215189873417, max: 53)
#
# Run: 80, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.15, max: 53)
#
# Run: 81, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.17283950617284, max: 53)
#
# Run: 82, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.317073170731707, max: 53)
#
# Run: 83, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.433734939759036, max: 53)
#
# Run: 84, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.511904761904763, max: 53)
#
# Run: 85, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.494117647058824, max: 53)
#
# Run: 86, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.5, max: 53)
#
# Run: 87, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.425287356321839, max: 53)
#
# Run: 88, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.431818181818182, max: 53)
#
# Run: 89, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.47191011235955, max: 53)
#
# Run: 90, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.422222222222222, max: 53)
#
# Run: 91, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.45054945054945, max: 53)
#
# Run: 92, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.467391304347826, max: 53)
#
# Run: 93, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.451612903225806, max: 53)
#
# Run: 94, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 15.627659574468085, max: 53)
#
# Run: 95, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.715789473684211, max: 53)
# Run: 96, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.71875, max: 53)
#
# Run: 97, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 16.690721649484537, max: 110)
#
# Run: 98, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 16.989795918367346, max: 110)
#
# Run: 99, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.12121212121212, max: 110)
#
# Run: 100, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.17, max: 110)
#
# Run: 101, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.15, max: 110)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.07, max: 110)
#
# Run: 103, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.22, max: 110)
#
# Run: 104, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.2, max: 110)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.21, max: 110)
#
# Run: 106, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.3, max: 110)
#
# Run: 107, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.44, max: 110)
#
# Run: 108, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.49, max: 110)
#
# Run: 109, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.64, max: 110)
#
# Run: 110, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 17.86, max: 110)
#
# Run: 111, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 18.15, max: 110)
#
# Run: 112, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.33, max: 110)
#
# Run: 113, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 18.74, max: 110)
#
# Run: 114, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 19.1, max: 110)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.11, max: 110)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.11, max: 110)
#
# Run: 117, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.1, max: 110)
#
# Run: 118, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.11, max: 110)
#
# Run: 119, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.13, max: 110)
#
# Run: 120, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.15, max: 110)
#
# Run: 121, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.21, max: 110)
#
# Run: 122, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.33, max: 110)
#
# Run: 123, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.48, max: 110)
#
# Run: 124, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 19.82, max: 110)
#
# Run: 125, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 20.09, max: 110)
#
# Run: 126, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.16, max: 110)
#
# Run: 127, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.34, max: 110)
#
# Run: 128, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.46, max: 110)
#
# Run: 129, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.51, max: 110)
#
# Run: 130, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.55, max: 110)
#
# Run: 131, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 21.64, max: 118)
#
# Run: 132, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 24.17, max: 262)
#
# Run: 133, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 26.4, max: 262)
#
# Run: 134, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 26.91, max: 262)
#
# Run: 135, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 27.79, max: 262)
#
# Run: 136, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 28.73, max: 262)
#
# Run: 137, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 28.95, max: 262)
#
# Run: 138, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 30.71, max: 262)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 35.61, max: 500)
#
# Run: 140, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 36.27, max: 500)
#
# Run: 141, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 41.17, max: 500)
#
# Run: 142, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 44, max: 500)
#
# Run: 143, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 45, max: 500)
#
# Run: 144, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 46.15, max: 500)
#
# Run: 145, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 47.32, max: 500)
#
# Run: 146, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 48.25, max: 500)
#
# Run: 147, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 49.28, max: 500)
#
# Run: 148, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 50.11, max: 500)
#
# Run: 149, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 51.19, max: 500)
#
# Run: 150, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 51.81, max: 500)
#
# Run: 151, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 53.1, max: 500)
#
# Run: 152, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 54.64, max: 500)
#
# Run: 153, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 56.21, max: 500)
#
# Run: 154, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 57.75, max: 500)
#
# Run: 155, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 59.61, max: 500)
#
# Run: 156, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 61.55, max: 500)
#
# Run: 157, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 63.22, max: 500)
#
# Run: 158, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 64.38, max: 500)
#
# Run: 159, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 66.5, max: 500)
#
# Run: 160, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 68.06, max: 500)
#
# Run: 161, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 69.27, max: 500)
#
# Run: 162, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 70.41, max: 500)
#
# Run: 163, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 71.7, max: 500)
#
# Run: 164, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 74.01, max: 500)
#
# Run: 165, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 75.85, max: 500)
#
# Run: 166, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 76.8, max: 500)
#
# Run: 167, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 77.65, max: 500)
#
# Run: 168, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 78.59, max: 500)
#
# Run: 169, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 79.97, max: 500)
#
# Run: 170, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 80.49, max: 500)
#
# Run: 171, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 81.76, max: 500)
#
# Run: 172, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 82.73, max: 500)
#
# Run: 173, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 83.79, max: 500)
#
# Run: 174, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 86.53, max: 500)
#
# Run: 175, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 86.48, max: 500)
#
# Run: 176, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.11, max: 500)
#
# Run: 177, exploration: 0.01, score: 322
# Scores: (min: 8, avg: 88.8, max: 500)
#
# Run: 178, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 89.65, max: 500)
#
# Run: 179, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 91.53, max: 500)
#
# Run: 180, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 92.47, max: 500)
#
# Run: 181, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 93.56, max: 500)
#
# Run: 182, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 94.23, max: 500)
#
# Run: 183, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 98.98, max: 500)
#
# Run: 184, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 100.29, max: 500)
#
# Run: 185, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 101.36, max: 500)
#
# Run: 186, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 101.3, max: 500)
#
# Run: 187, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 101.73, max: 500)
#
# Run: 188, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 102.79, max: 500)
#
# Run: 189, exploration: 0.01, score: 458
# Scores: (min: 8, avg: 107.18, max: 500)
#
# Run: 190, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 108.11, max: 500)
#
# Run: 191, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 108.87, max: 500)
#
# Run: 192, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 110.14, max: 500)
#
# Run: 193, exploration: 0.01, score: 377
# Scores: (min: 8, avg: 113.77, max: 500)
#
# Run: 194, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 115.06, max: 500)
#
# Run: 195, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 116.66, max: 500)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 116.6, max: 500)
#
# Run: 197, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 115.58, max: 500)
#
# Run: 198, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 115.23, max: 500)
# Run: 199, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 115.03, max: 500)
#
# Run: 200, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.91, max: 500)
#
# Run: 201, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.8, max: 500)
#
# Run: 202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.79, max: 500)
#
# Run: 203, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.64, max: 500)
#
# Run: 204, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 114.64, max: 500)
#
# Run: 205, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.63, max: 500)
#
# Run: 206, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.53, max: 500)
#
# Run: 207, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.4, max: 500)
#
# Run: 208, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 114.36, max: 500)
#
# Run: 209, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.21, max: 500)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 113.99, max: 500)
#
# Run: 211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 113.69, max: 500)
#
# Run: 212, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 113.5, max: 500)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 113.09, max: 500)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.74, max: 500)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.74, max: 500)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.75, max: 500)
#
# Run: 217, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 112.74, max: 500)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.73, max: 500)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.72, max: 500)
#
# Run: 220, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 112.72, max: 500)
#
# Run: 221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.67, max: 500)
#
# Run: 222, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 112.54, max: 500)
#
# Run: 223, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.4, max: 500)
#
# Run: 224, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.05, max: 500)
#
# Run: 225, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 111.78, max: 500)
#
# Run: 226, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 111.73, max: 500)
#
# Run: 227, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 111.52, max: 500)
#
# Run: 228, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 111.38, max: 500)
#
# Run: 229, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 111.33, max: 500)
#
# Run: 230, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 111.26, max: 500)
#
# Run: 231, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 110.17, max: 500)
#
# Run: 232, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 107.64, max: 500)
#
# Run: 233, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 105.45, max: 500)
#
# Run: 234, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 104.8, max: 500)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 103.92, max: 500)
#
# Run: 236, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 102.98, max: 500)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 102.73, max: 500)
#
# Run: 238, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 100.96, max: 500)
#
# Run: 239, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 96.06, max: 500)
#
# Run: 240, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 95.4, max: 500)
#
# Run: 241, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 90.48, max: 500)
#
# Run: 242, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.66, max: 500)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 86.66, max: 500)
#
# Run: 244, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 85.49, max: 500)
#
# Run: 245, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 84.32, max: 500)
#
# Run: 246, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 83.35, max: 500)
#
# Run: 247, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 82.28, max: 500)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 81.41, max: 500)
#
# Run: 249, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.34, max: 500)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 79.71, max: 500)
#
# Run: 251, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78.43, max: 500)
#
# Run: 252, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 76.89, max: 500)
#
# Run: 253, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 75.97, max: 500)
#
# Run: 254, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.43, max: 500)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.58, max: 500)
#
# Run: 256, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 70.26, max: 500)
#
# Run: 257, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 68.52, max: 500)
#
# Run: 258, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 67.13, max: 500)
#
# Run: 259, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.85, max: 500)
#
# Run: 260, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 63.2, max: 500)
#
# Run: 261, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 61.85, max: 500)
#
# Run: 262, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.59, max: 500)
#
# Run: 263, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 59.12, max: 500)
#
# Run: 264, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 56.82, max: 500)
#
# Run: 265, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 54.97, max: 500)
#
# Run: 266, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.88, max: 500)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.87, max: 500)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.74, max: 500)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 50.2, max: 500)
#
# Run: 270, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.56, max: 500)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.26, max: 500)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.15, max: 500)
#
# Run: 273, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.95, max: 500)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.11, max: 500)
#
# Run: 275, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.95, max: 500)
#
# Run: 276, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 43.14, max: 500)
#
# Run: 277, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.01, max: 500)
#
# Run: 278, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.05, max: 500)
#
# Run: 279, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.87, max: 500)
#
# Run: 280, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.89, max: 500)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.73, max: 500)
#
# Run: 282, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.88, max: 500)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.97, max: 458)
#
# Run: 284, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.54, max: 458)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.42, max: 458)
#
# Run: 286, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.41, max: 458)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.98, max: 458)
#
# Run: 288, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 25.19, max: 458)
#
# Run: 289, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 20.87, max: 377)
#
# Run: 290, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.91, max: 377)
#
# Run: 291, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 19.36, max: 377)
#
# Run: 292, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 18.58, max: 377)
#
# Run: 293, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 15.55, max: 184)
#
# Run: 294, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 14.42, max: 184)
#
# Run: 295, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 13.15, max: 75)
#
# Run: 296, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 14.07, max: 102)
#
# Run: 297, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.25, max: 102)
#
# Run: 298, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 14.62, max: 102)
#
# Run: 299, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 14.98, max: 102)
#
# Run: 300, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 15.43, max: 102)
#
# Run: 301, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 16.67, max: 133)
#
# Run: 302, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 17.65, max: 133)
# Run: 303, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 18.54, max: 133)
#
# Run: 304, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 18.96, max: 133)
#
# Run: 305, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 19.28, max: 133)
#
# Run: 306, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 19.77, max: 133)
#
# Run: 307, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.92, max: 133)
#
# Run: 308, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.03, max: 133)
#
# Run: 309, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.11, max: 133)
#
# Run: 310, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.19, max: 133)
#
# Run: 311, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 21.24, max: 133)
#
# Run: 312, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 21.8, max: 133)
#
# Run: 313, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 22.76, max: 133)
#
# Run: 314, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.85, max: 133)
#
# Run: 315, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.97, max: 133)
#
# Run: 316, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 23.05, max: 133)
#
# Run: 317, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.17, max: 133)
#
# Run: 318, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 23.22, max: 133)
#
# Run: 319, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 23.3, max: 133)
#
# Run: 320, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.39, max: 133)
#
# Run: 321, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.45, max: 133)
#
# Run: 322, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 23.87, max: 133)
#
# Run: 323, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 25.95, max: 217)
#
# Run: 324, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 26.02, max: 217)
#
# Run: 325, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 26.19, max: 217)
#
# Run: 326, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 26.59, max: 217)
#
# Run: 327, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 26.79, max: 217)
#
# Run: 328, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 26.99, max: 217)
#
# Run: 329, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 27.4, max: 217)
#
# Run: 330, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 27.44, max: 217)
#
# Run: 331, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 27.5, max: 217)
#
# Run: 332, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.55, max: 217)
#
# Run: 333, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.53, max: 217)
#
# Run: 334, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.58, max: 217)
#
# Run: 335, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 27.6, max: 217)
#
# Run: 336, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.65, max: 217)
#
# Run: 337, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.7, max: 217)
#
# Run: 338, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 27.75, max: 217)
#
# Run: 339, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 28.01, max: 217)
#
# Run: 340, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 28.36, max: 217)
#
# Run: 341, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 28.64, max: 217)
#
# Run: 342, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.66, max: 217)
#
# Run: 343, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 28.69, max: 217)
#
# Run: 344, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.72, max: 217)
#
# Run: 345, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.74, max: 217)
#
# Run: 346, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 29.18, max: 217)
#
# Run: 347, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 29.22, max: 217)
#
# Run: 348, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.24, max: 217)
#
# Run: 349, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 29.26, max: 217)
#
# Run: 350, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 29.29, max: 217)
#
# Run: 351, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 29.81, max: 217)
#
# Run: 352, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 29.85, max: 217)
#
# Run: 353, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.21, max: 217)
#
# Run: 354, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.22, max: 217)
#
# Run: 355, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 29.25, max: 217)
#
# Run: 356, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.25, max: 217)
#
# Run: 357, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.27, max: 217)
#
# Run: 358, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.26, max: 217)
#
# Run: 359, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 29.28, max: 217)
#
# Run: 360, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 29.53, max: 217)
#
# Run: 361, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 29.57, max: 217)
#
# Run: 362, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 29.77, max: 217)
#
# Run: 363, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.77, max: 217)
#
# Run: 364, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.77, max: 217)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.77, max: 217)
#
# Run: 366, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.78, max: 217)
#
# Run: 367, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 29.8, max: 217)
#
# Run: 368, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 29.9, max: 217)
#
# Run: 369, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 29.93, max: 217)
#
# Run: 370, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 29.99, max: 217)
#
# Run: 371, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 30.03, max: 217)
#
# Run: 372, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 30.34, max: 217)
#
# Run: 373, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.39, max: 217)
#
# Run: 374, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.44, max: 217)
#
# Run: 375, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.5, max: 217)
#
# Run: 376, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 30.65, max: 217)
#
# Run: 377, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 32.72, max: 217)
#
# Run: 378, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 33.84, max: 217)
#
# Run: 379, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 34.74, max: 217)
#
# Run: 380, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 35.65, max: 217)
#
# Run: 381, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 36.39, max: 217)
#
# Run: 382, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 36.65, max: 217)
#
# Run: 383, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 36.68, max: 217)
#
# Run: 384, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.68, max: 217)
#
# Run: 385, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.69, max: 217)
#
# Run: 386, exploration: 0.01, score: 363
# Scores: (min: 8, avg: 40.23, max: 363)
#
# Run: 387, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 40.68, max: 363)
#
# Run: 388, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 41.49, max: 363)
#
# Run: 389, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 46.23, max: 500)
#
# Run: 390, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 46.88, max: 500)
#
# Run: 391, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 47.89, max: 500)
#
# Run: 392, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 49.39, max: 500)
#
# Run: 393, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 48.73, max: 500)
#
# Run: 394, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 48.35, max: 500)
#
# Run: 395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.88, max: 500)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.96, max: 500)
#
# Run: 397, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 48.92, max: 500)
#
# Run: 398, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 50.04, max: 500)
#
# Run: 399, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 51.26, max: 500)
#
# Run: 400, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 52.14, max: 500)
#
# Run: 401, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 52.95, max: 500)
#
# Run: 402, exploration: 0.01, score: 393
# Scores: (min: 8, avg: 55.81, max: 500)
#
# Run: 403, exploration: 0.01, score: 476
# Scores: (min: 8, avg: 59.58, max: 500)
#
# Run: 404, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 60.02, max: 500)
#
# Run: 405, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 60.22, max: 500)
#
# Run: 406, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 60.88, max: 500)
# Run: 407, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 62, max: 500)
#
# Run: 408, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 63.52, max: 500)
#
# Run: 409, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 64.11, max: 500)
#
# Run: 410, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 64.12, max: 500)
#
# Run: 411, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 63.95, max: 500)
#
# Run: 412, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 63.4, max: 500)
#
# Run: 413, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 62.57, max: 500)
#
# Run: 414, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 62.52, max: 500)
#
# Run: 415, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 62.43, max: 500)
#
# Run: 416, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 62.44, max: 500)
#
# Run: 417, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 62.35, max: 500)
#
# Run: 418, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 62.31, max: 500)
#
# Run: 419, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 62.26, max: 500)
#
# Run: 420, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 62.15, max: 500)
#
# Run: 421, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 62.09, max: 500)
#
# Run: 422, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 61.73, max: 500)
#
# Run: 423, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 59.83, max: 500)
#
# Run: 424, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 59.75, max: 500)
#
# Run: 425, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 59.56, max: 500)
#
# Run: 426, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 59.29, max: 500)
#
# Run: 427, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 59.11, max: 500)
#
# Run: 428, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 58.95, max: 500)
#
# Run: 429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 58.55, max: 500)
#
# Run: 430, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 58.55, max: 500)
#
# Run: 431, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 58.52, max: 500)
#
# Run: 432, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 59.39, max: 500)
#
# Run: 433, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 61.42, max: 500)
#
# Run: 434, exploration: 0.01, score: 278
# Scores: (min: 8, avg: 64.06, max: 500)
#
# Run: 435, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 65.22, max: 500)
#
# Run: 436, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 66.39, max: 500)
#
# Run: 437, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 68.41, max: 500)
#
# Run: 438, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 69.47, max: 500)
#
# Run: 439, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 70.74, max: 500)
#
# Run: 440, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 71.76, max: 500)
#
# Run: 441, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 72.92, max: 500)
#
# Run: 442, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 74.47, max: 500)
#
# Run: 443, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 76.28, max: 500)
#
# Run: 444, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 77.78, max: 500)
#
# Run: 445, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 79.29, max: 500)
#
# Run: 446, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 80.17, max: 500)
#
# Run: 447, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 82.62, max: 500)
#
# Run: 448, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 83.78, max: 500)
#
# Run: 449, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 85.14, max: 500)
#
# Run: 450, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 86.31, max: 500)
#
# Run: 451, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 87.22, max: 500)
#
# Run: 452, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 88.68, max: 500)
#
# Run: 453, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 89.39, max: 500)
#
# Run: 454, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 89.58, max: 500)
#
# Run: 455, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 90.36, max: 500)
#
# Run: 456, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 91.14, max: 500)
#
# Run: 457, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 92.46, max: 500)
#
# Run: 458, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 93.57, max: 500)
#
# Run: 459, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 94.39, max: 500)
#
# Run: 460, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 95.54, max: 500)
#
# Run: 461, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 96.72, max: 500)
#
# Run: 462, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 98.65, max: 500)
#
# Run: 463, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 99.38, max: 500)
#
# Run: 464, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 100.55, max: 500)
#
# Run: 465, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 103.36, max: 500)
#
# Run: 466, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 104.1, max: 500)
#
# Run: 467, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 105.43, max: 500)
#
# Run: 468, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 106.66, max: 500)
#
# Run: 469, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 107.99, max: 500)
#
# Run: 470, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 109.45, max: 500)
#
# Run: 471, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 110.7, max: 500)
#
# Run: 472, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 112.68, max: 500)
#
# Run: 473, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 114.04, max: 500)
#
# Run: 474, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 116.01, max: 500)
#
# Run: 475, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 117.55, max: 500)
#
# Run: 476, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 119.55, max: 500)
#
# Run: 477, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 118.86, max: 500)
#
# Run: 478, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 119.38, max: 500)
#
# Run: 479, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 119.71, max: 500)
#
# Run: 480, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 120.09, max: 500)
#
# Run: 481, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 121.59, max: 500)
#
# Run: 482, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 122.57, max: 500)
#
# Run: 483, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 124.48, max: 500)
#
# Run: 484, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 126.18, max: 500)
#
# Run: 485, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 128.24, max: 500)
#
# Run: 486, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 126.18, max: 500)
#
# Run: 487, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 127.19, max: 500)
#
# Run: 488, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 128.28, max: 500)
#
# Run: 489, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 125.15, max: 476)
#
# Run: 490, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 125.95, max: 476)
#
# Run: 491, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 126.41, max: 476)
#
# Run: 492, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 126.54, max: 476)
#
# Run: 493, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 128.47, max: 476)
#
# Run: 494, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 130.03, max: 476)
#
# Run: 495, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 131.5, max: 476)
#
# Run: 496, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 133.38, max: 476)
#
# Run: 497, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 132.11, max: 476)
#
# Run: 498, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 132.41, max: 476)
#
# Run: 499, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 132.42, max: 476)
#
# Run: 500, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 132.64, max: 476)
#
# Run: 501, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 131.94, max: 476)
#
# Run: 502, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 129.46, max: 476)
#
# Run: 503, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 125.13, max: 291)
#
# Run: 504, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 125.49, max: 291)
#
# Run: 505, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 125.46, max: 291)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 124.32, max: 291)
#
# Run: 507, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 123.49, max: 291)
#
# Run: 508, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 121.91, max: 291)
#
# Run: 509, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.24, max: 291)
# Run: 510, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 121.17, max: 291)
#
# Run: 511, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 120.38, max: 291)
#
# Run: 512, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 120.55, max: 291)
#
# Run: 513, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 120.41, max: 291)
#
# Run: 514, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 120.37, max: 291)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 120.35, max: 291)
#
# Run: 516, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 120.34, max: 291)
#
# Run: 517, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 120.34, max: 291)
#
# Run: 518, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 120.34, max: 291)
#
# Run: 519, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 120.34, max: 291)
#
# Run: 520, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 120.44, max: 291)
#
# Run: 521, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 120.48, max: 291)
#
# Run: 522, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 120.49, max: 291)
#
# Run: 523, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 120.39, max: 291)
#
# Run: 524, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 120.45, max: 291)
#
# Run: 525, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 120.59, max: 291)
#
# Run: 526, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 120.58, max: 291)
#
# Run: 527, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 120.86, max: 291)
#
# Run: 528, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 121.46, max: 291)
#
# Run: 529, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 122.11, max: 291)
#
# Run: 530, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 123.02, max: 291)
#
# Run: 531, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 123.96, max: 291)
#
# Run: 532, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 124.61, max: 291)
#
# Run: 533, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 125.04, max: 291)
#
# Run: 534, exploration: 0.01, score: 425
# Scores: (min: 9, avg: 126.51, max: 425)
#
# Run: 535, exploration: 0.01, score: 275
# Scores: (min: 9, avg: 127.98, max: 425)
#
# Run: 536, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 128.7, max: 425)
#
# Run: 537, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 128.68, max: 425)
#
# Run: 538, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 129.65, max: 425)
#
# Run: 539, exploration: 0.01, score: 436
# Scores: (min: 9, avg: 132.38, max: 436)
#
# Run: 540, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 132.42, max: 436)
#
# Run: 541, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 132.28, max: 436)
#
# Run: 542, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 132.12, max: 436)
#
# Run: 543, exploration: 0.01, score: 407
# Scores: (min: 9, avg: 134.25, max: 436)
#
# Run: 544, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 137.64, max: 500)
#
# Run: 545, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 141.02, max: 500)
#
# Run: 546, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 144.6, max: 500)
#
# Run: 547, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 144.1, max: 500)
#
# Run: 548, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 144.1, max: 500)
#
# Run: 549, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 144.88, max: 500)
#
# Run: 550, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 145, max: 500)
#
# Run: 551, exploration: 0.01, score: 275
# Scores: (min: 9, avg: 146.22, max: 500)
#
# Run: 552, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 146.41, max: 500)
#
# Run: 553, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 146.92, max: 500)
#
# Run: 554, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 149.59, max: 500)
#
# Run: 555, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 151.76, max: 500)
#
# Run: 556, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 152.26, max: 500)
#
# Run: 557, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 152.84, max: 500)
#
# Run: 558, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 153.03, max: 500)
#
# Run: 559, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 154.13, max: 500)
#
# Run: 560, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 157.63, max: 500)
#
# Run: 561, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 157.31, max: 500)
#
# Run: 562, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 156.68, max: 500)
#
# Run: 563, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 158.59, max: 500)
#
# Run: 564, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 158.84, max: 500)
#
# Run: 565, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 157.61, max: 500)
#
# Run: 566, exploration: 0.01, score: 443
# Scores: (min: 9, avg: 161.19, max: 500)
#
# Run: 567, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 164.74, max: 500)
#
# Run: 568, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 163.73, max: 500)
#
# Run: 569, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 162.38, max: 500)
#
# Run: 570, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 160.9, max: 500)
#
# Run: 571, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 159.62, max: 500)
#
# Run: 572, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 157.4, max: 500)
#
# Run: 573, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 155.98, max: 500)
#
# Run: 574, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 153.95, max: 500)
#
# Run: 575, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 152.35, max: 500)
#
# Run: 576, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 150.03, max: 500)
#
# Run: 577, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 148.64, max: 500)
#
# Run: 578, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 147.97, max: 500)
#
# Run: 579, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 149.69, max: 500)
#
# Run: 580, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 149.33, max: 500)
#
# Run: 581, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 147.81, max: 500)
#
# Run: 582, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 147.93, max: 500)
#
# Run: 583, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 147.94, max: 500)
#
# Run: 584, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 148.5, max: 500)
#
# Run: 585, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 146.88, max: 500)
#
# Run: 586, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 146.41, max: 500)
#
# Run: 587, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 146.89, max: 500)
#
# Run: 588, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 146.24, max: 500)
#
# Run: 589, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 146.33, max: 500)
#
# Run: 590, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 145.99, max: 500)
#
# Run: 591, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 146.17, max: 500)
#
# Run: 592, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 145.97, max: 500)
#
# Run: 593, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 145.34, max: 500)
#
# Run: 594, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 145.58, max: 500)
#
# ...
# Scores: (min: 8, avg: 69.62, max: 256)
#
# Run: 1030, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.37, max: 256)
#
# Run: 1031, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 69.31, max: 256)
#
# Run: 1032, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.17, max: 256)
#
# Run: 1033, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 69.04, max: 256)
#
# Run: 1034, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 68.85, max: 256)
#
# Run: 1035, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 68.89, max: 256)
#
# Run: 1036, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 68.79, max: 256)
#
# Run: 1037, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 68.41, max: 256)
#
# Run: 1038, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 68.03, max: 256)
#
# Run: 1039, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.65, max: 256)
#
# Run: 1040, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.36, max: 256)
#
# Run: 1041, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 67.09, max: 256)
#
# Run: 1042, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 66.8, max: 256)
#
# Run: 1043, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.12, max: 256)
#
# Run: 1044, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 65.5, max: 256)
#
# Run: 1045, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 65.79, max: 256)
#
# Run: 1046, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 66.31, max: 256)
#
# Run: 1047, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 65.61, max: 256)
#
# Run: 1048, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 64.99, max: 256)
#
# Run: 1049, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.52, max: 256)
#
# Run: 1050, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 64.53, max: 256)
#
# Run: 1051, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 63.9, max: 256)
#
# Run: 1052, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 63.06, max: 256)
#
# Run: 1053, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 62.69, max: 256)
#
# Run: 1054, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 62.35, max: 256)
#
# Run: 1055, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 61.51, max: 256)
#
# Run: 1056, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 59.76, max: 256)
#
# Run: 1057, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 60.19, max: 256)
#
# Run: 1058, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 62.47, max: 256)
#
# Run: 1059, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 62.94, max: 256)
#
# Run: 1060, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 63.87, max: 256)
#
# Run: 1061, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 63.72, max: 256)
#
# Run: 1062, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 63.27, max: 256)
#
# Run: 1063, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 63.38, max: 256)
#
# Run: 1064, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 63.77, max: 256)
#
# Run: 1065, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 63.56, max: 256)
#
# Run: 1066, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 62.85, max: 256)
#
# Run: 1067, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 65.73, max: 310)
#
# Run: 1068, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 65.68, max: 310)
#
# Run: 1069, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 66.26, max: 310)
#
# Run: 1070, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 66.19, max: 310)
#
# Run: 1071, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.97, max: 310)
#
# Run: 1072, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 63.86, max: 310)
#
# Run: 1073, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 65.24, max: 310)
#
# Run: 1074, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 66.66, max: 310)
#
# Run: 1075, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 68.56, max: 310)
#
# Run: 1076, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 69.2, max: 310)
#
# Run: 1077, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 68.9, max: 310)
#
# Run: 1078, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 68.09, max: 310)
#
# Run: 1079, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 68.58, max: 310)
#
# Run: 1080, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 69.19, max: 310)
#
# Run: 1081, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 68.26, max: 310)
#
# Run: 1082, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 67.76, max: 310)
#
# Run: 1083, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 68.71, max: 310)
#
# Run: 1084, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.88, max: 310)
#
# Run: 1085, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.27, max: 310)
#
# Run: 1086, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 66.35, max: 310)
#
# Run: 1087, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 64.02, max: 310)
#
# Run: 1088, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 64.03, max: 310)
#
# Run: 1089, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 63.93, max: 310)
#
# Run: 1090, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 63.47, max: 310)
#
# Run: 1091, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 62.03, max: 310)
#
# Run: 1092, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 62, max: 310)
#
# Run: 1093, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 61.61, max: 310)
#
# Run: 1094, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 61.25, max: 310)
#
# Run: 1095, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 61.31, max: 310)
#
# Run: 1096, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 61.4, max: 310)
#
# Run: 1097, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 60.31, max: 310)
#
# Run: 1098, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 60.84, max: 310)
#
# Run: 1099, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 62.86, max: 310)
#
# Run: 1100, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 64.02, max: 310)
#
# Run: 1101, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 63.29, max: 310)
#
# Run: 1102, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 63.06, max: 310)
#
# Run: 1103, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 63.84, max: 310)
#
# Run: 1104, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 64.98, max: 310)
#
# Run: 1105, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 65.12, max: 310)
#
# Run: 1106, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 65.6, max: 310)
#
# Run: 1107, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 68.29, max: 310)
#
# Run: 1108, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 68.58, max: 310)
#
# Run: 1109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.63, max: 310)
#
# Run: 1110, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 67.15, max: 310)
#
# Run: 1111, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 67.12, max: 310)
#
# Run: 1112, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 68.63, max: 310)
#
# Run: 1113, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 68.83, max: 310)
#
# Run: 1114, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 69.31, max: 310)
#
# Run: 1115, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 69.22, max: 310)
#
# Run: 1116, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 68.35, max: 310)
#
# Run: 1117, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 69.68, max: 310)
#
# Run: 1118, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 69.21, max: 310)
#
# Run: 1119, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 70.9, max: 310)
#
# Run: 1120, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 72.03, max: 310)
#
# Run: 1121, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 73.79, max: 310)
#
# Run: 1122, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 72.42, max: 310)
#
# Run: 1123, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 73.08, max: 310)
#
# Run: 1124, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 74.99, max: 310)
#
# Run: 1125, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 76.89, max: 310)
#
# Run: 1126, exploration: 0.01, score: 382
# Scores: (min: 8, avg: 80.61, max: 382)
#
# Run: 1127, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 81.49, max: 382)
#
# Run: 1128, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 83.01, max: 382)
#
# Run: 1129, exploration: 0.01, score: 485
# Scores: (min: 8, avg: 87.52, max: 485)
#
# Run: 1130, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 89.12, max: 485)
# Run: 1131, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 89.25, max: 485)
#
# Run: 1132, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 89.25, max: 485)
#
# Run: 1133, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 89.82, max: 485)
#
# Run: 1134, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 90.2, max: 485)
#
# Run: 1135, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 91.49, max: 485)
#
# Run: 1136, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 92.87, max: 485)
#
# Run: 1137, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 95.77, max: 485)
#
# Run: 1138, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 96.59, max: 485)
#
# Run: 1139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 96.6, max: 485)
#
# Run: 1140, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 96.66, max: 485)
#
# Run: 1141, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 98.18, max: 485)
#
# Run: 1142, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 99.29, max: 485)
#
# Run: 1143, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 100.62, max: 485)
#
# Run: 1144, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 102.49, max: 485)
#
# Run: 1145, exploration: 0.01, score: 343
# Scores: (min: 8, avg: 104.65, max: 485)
#
# Run: 1146, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 105.77, max: 485)
#
# Run: 1147, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 106.02, max: 485)
#
# Run: 1148, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 106.46, max: 485)
#
# Run: 1149, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 107.05, max: 485)
#
# Run: 1150, exploration: 0.01, score: 279
# Scores: (min: 8, avg: 109.75, max: 485)
#
# Run: 1151, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 110.67, max: 485)
#
# Run: 1152, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 111.6, max: 485)
#
# Run: 1153, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 112.91, max: 485)
#
# Run: 1154, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 112.96, max: 485)
#
# Run: 1155, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 113.71, max: 485)
#
# Run: 1156, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 114.71, max: 485)
#
# Run: 1157, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 115.83, max: 485)
#
# Run: 1158, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 115.78, max: 485)
#
# Run: 1159, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 116.86, max: 485)
#
# Run: 1160, exploration: 0.01, score: 360
# Scores: (min: 9, avg: 119.44, max: 485)
#
# Run: 1161, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 120.66, max: 485)
#
# Run: 1162, exploration: 0.01, score: 381
# Scores: (min: 9, avg: 124.27, max: 485)
#
# Run: 1163, exploration: 0.01, score: 421
# Scores: (min: 9, avg: 127.48, max: 485)
#
# Run: 1164, exploration: 0.01, score: 435
# Scores: (min: 9, avg: 130.37, max: 485)
#
# Run: 1165, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 133.02, max: 485)
#
# Run: 1166, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 135.06, max: 485)
#
# Run: 1167, exploration: 0.01, score: 342
# Scores: (min: 9, avg: 135.38, max: 485)
#
# Run: 1168, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 136.52, max: 485)
#
# Run: 1169, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 136.43, max: 485)
#
# Run: 1170, exploration: 0.01, score: 341
# Scores: (min: 9, avg: 138.33, max: 485)
#
# Run: 1171, exploration: 0.01, score: 351
# Scores: (min: 9, avg: 141.74, max: 485)
#
# Run: 1172, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 142.49, max: 485)
#
# Run: 1173, exploration: 0.01, score: 326
# Scores: (min: 9, avg: 144.2, max: 485)
#
# Run: 1174, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 145.51, max: 485)
#
# Run: 1175, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 146.29, max: 485)
#
# Run: 1176, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 145.24, max: 485)
#
# Run: 1177, exploration: 0.01, score: 291
# Scores: (min: 9, avg: 147.51, max: 485)
#
# Run: 1178, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 147.9, max: 485)
#
# Run: 1179, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 146.95, max: 485)
#
# Run: 1180, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 146.79, max: 485)
#
# Run: 1181, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 150.82, max: 500)
#
# Run: 1182, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 155.46, max: 500)
#
# Run: 1183, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 156.51, max: 500)
#
# Run: 1184, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 157.69, max: 500)
#
# Run: 1185, exploration: 0.01, score: 298
# Scores: (min: 9, avg: 160.57, max: 500)
#
# Run: 1186, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 163.05, max: 500)
#
# Run: 1187, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 163.91, max: 500)
#
# Run: 1188, exploration: 0.01, score: 324
# Scores: (min: 9, avg: 166.92, max: 500)
#
# Run: 1189, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 169.45, max: 500)
#
# Run: 1190, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 169.79, max: 500)
#
# Run: 1191, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 169.73, max: 500)
#
# Run: 1192, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 170.48, max: 500)
#
# Run: 1193, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 175.15, max: 500)
#
# Run: 1194, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 175.97, max: 500)
#
# Run: 1195, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 177.7, max: 500)
#
# Run: 1196, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 177.17, max: 500)
#
# Run: 1197, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 176.66, max: 500)
#
# Run: 1198, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 175.69, max: 500)
#
# Run: 1199, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 173.65, max: 500)
#
# Run: 1200, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 171.4, max: 500)
#
# Run: 1201, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 170.67, max: 500)
#
# Run: 1202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 170.09, max: 500)
#
# Run: 1203, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 169.25, max: 500)
#
# Run: 1204, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 168.11, max: 500)
#
# Run: 1205, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 167.97, max: 500)
#
# Run: 1206, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 167.49, max: 500)
#
# Run: 1207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 164.74, max: 500)
#
# Run: 1208, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 164.44, max: 500)
#
# Run: 1209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 164.44, max: 500)
#
# Run: 1210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 163.62, max: 500)
#
# Run: 1211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 162.22, max: 500)
#
# Run: 1212, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 160.7, max: 500)
#
# Run: 1213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 160.31, max: 500)
#
# Run: 1214, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 159.51, max: 500)
#
# Run: 1215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 158.92, max: 500)
#
# Run: 1216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 158.72, max: 500)
#
# Run: 1217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 156.53, max: 500)
#
# Run: 1218, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 155.53, max: 500)
#
# Run: 1219, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 153.44, max: 500)
#
# Run: 1220, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 152.31, max: 500)
#
# Run: 1221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.56, max: 500)
#
# Run: 1222, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 150.37, max: 500)
#
# Run: 1223, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 148.94, max: 500)
#
# Run: 1224, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.1, max: 500)
#
# Run: 1225, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 144.19, max: 500)
#
# Run: 1226, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 141.83, max: 500)
#
# Run: 1227, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 142.15, max: 500)

# %% [markdown]
# Understanding the Cartpole Problem with Reinforcement Learning
#
# How Does Reinforcement Learning Apply to Cartpole?
# In the Cartpole problem, we use reinforcement learning to teach an agent how to balance a pole on a moving cart. The agent makes decisions based on the current state of the system, and over time, it learns how to maximize rewards by keeping the pole upright for as long as possible.
# Goal of the Agent: The agent’s main goal is simple—keep the pole balanced. Every time the pole stays upright, the agent earns a reward. The longer it can balance the pole, the better the outcome (Surma, 2018).
# State Values: The agent tracks four things to understand the environment: the cart's position, its velocity, the angle of the pole, and the speed at which the pole is tipping (Lamba, 2018).
# Actions: The agent has two possible moves: push the cart left or push it right (Düğmeci, 2018).
# Algorithm Used: For this task, we use Deep Q-Learning (DQN). The DQN algorithm uses a neural network to estimate the best action the agent should take based on the current state (Surma, 2018).
#
# How Does Experience Replay Work in Cartpole?
# Experience Replay: As the agent interacts with the environment, it stores these interactions in memory. Later, it randomly picks from this memory to learn, which helps the agent avoid focusing too much on what happened recently and makes the learning process more stable (Düğmeci, 2018).
# The Role of the Discount Factor: The discount factor (GAMMA) helps the agent balance immediate and future rewards. A higher discount factor encourages the agent to look further into the future when deciding its actions, while a lower value makes it focus more on the here and now (Lamba, 2018).
#
# How Neural Networks Improve Deep Q-Learning
# The Network: In this case, the agent’s brain is a neural network with two hidden layers, each having 24 neurons. The input layer takes in the four key state values (cart position, velocity, pole angle, and angular velocity), and the output layer provides the Q-values, which indicate the expected reward for each possible action (Surma, 2018).
# Why Use a Neural Network?: Using a neural network makes Q-learning more efficient, especially in a complex environment like Cartpole where the state space is continuous. Instead of using traditional methods that would require a large table of values, the network allows the agent to generalize from what it learns, which speeds up the decision-making process (Lamba, 2018).
#
# How Does the Learning Rate Affect Performance?
# Learning Rate Impact: The learning rate (LEARNING_RATE) controls how quickly the neural network updates its understanding of the world. If the learning rate is too high, the agent can struggle to find a stable solution. If it’s too low, the agent will take longer to learn. Finding the right balance is key to ensuring the agent learns efficiently. Typically, a slightly higher learning rate can improve performance, but if it’s too high, the training can become unstable (Surma, 2018).
#
# Summary of experiments:
# In Experiment 1, I slowed the exploration decay (EXPLORATION_DECAY = 0.9), allowing the agent to spend more time exploring different strategies before focusing on exploiting the best ones. This change led to faster convergence compared to Run 1, as the agent had more opportunities to gather diverse experiences and improve its decision-making. However, in Experiment 3, I increased the learning rate to 0.01 to speed up the learning process. Despite running 2000 times, the agent didn’t solve the problem. The higher learning rate caused the updates to be too aggressive, leading to instability in the learning process and preventing the agent from converging to an optimal solution. While the slower exploration in Experiment 1 encouraged balanced learning, the overly high learning rate in Experiment 3 disrupted the agent’s ability to learn effectively.
#
# References:
# Düğmeci, D. (2018). Finding shortest path using Q-learning algorithm. Towards Data Science. Retrieved from https://towardsdatascience.com
# Lamba, A. (2018). An introduction to Q-learning: Reinforcement learning. freeCodeCamp News. Retrieved from https://freecodecamp.org
# Surma, G. (2018). Cartpole: Introduction to reinforcement learning (DQN - Deep Q-learning). Medium. Retrieved from https://github.com/gsurma/cartpole
